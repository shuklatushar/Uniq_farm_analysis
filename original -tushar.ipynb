# %%
import pandas as pd
import glob
import os
import warnings
import matplotlib.pyplot as plt
import matplotlib
warnings.filterwarnings("ignore")

# %%
print(os.getcwd())
# Out:
# C:\Users\Manshi\Desktop\razorpay

# %%
directory = r'C:\Users\Manshi\Desktop\razorpay\\'
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# %%
csv_files
# Out:
# ['payment_links - 04 Jun 23 - 04 Jun 23 (1).csv',
#  'payment_links - 04 Jun 23 - 04 Jun 23 (2).csv',
#  'payment_links - 04 Jun 23 - 04 Jun 23.csv',
#  'payment_links - 05 May 23 - 05 May 23 (1).csv',
#  'payment_links - 05 May 23 - 05 May 23 (2).csv',
#  'payment_links - 05 May 23 - 05 May 23 (3).csv',
#  'payment_links - 05 May 23 - 05 May 23 (4).csv',
#  'payment_links - 05 May 23 - 05 May 23.csv',
#  'payment_links - 12 May 23 - 12 May 23 (1).csv',
#  'payment_links - 12 May 23 - 12 May 23 (2).csv',
#  'payment_links - 12 May 23 - 12 May 23.csv',
#  'payment_links - 15 May 23 - 15 May 23 (1).csv',
#  'payment_links - 15 May 23 - 15 May 23.csv',
#  'payment_links - 21 May 23 - 21 May 23 (1).csv',
#  'payment_links - 21 May 23 - 21 May 23 (2).csv',
#  'payment_links - 21 May 23 - 21 May 23 (3).csv',
#  'payment_links - 21 May 23 - 21 May 23.csv',
#  'payment_links - 24 May 23 - 24 May 23.csv',
#  'payment_links - 28 May 23 - 28 May 23 (1).csv',
#  'payment_links - 28 May 23 - 28 May 23.csv',
#  'payment_links - 31 May 23 - 31 May 23.csv']

# %%
combined_data = pd.DataFrame()

# %%
for files in csv_files:
    data=pd.read_csv(files)
    combined_data = pd.concat([combined_data,data],ignore_index=True)

# %%
combined_data.head()
# Out:
#      payment page id                 payment page title         payment date  \
# 0  pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10  09/06/2023 08:13:40
# 1  pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10  09/06/2023 08:13:40
# 2  pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10  09/06/2023 08:13:40
# 3  pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10  09/06/2023 20:53:00
# 4  pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10  09/06/2023 20:53:00
#
#                order_id          item name  item amount  item quantity  \
# 0  order_LzfdbQw8rMiwPF   MIXED SEEDS 250G        385.0              1
# 1  order_LzfdbQw8rMiwPF       WALNUTS 500G       1155.0              1
# 2  order_LzfdbQw8rMiwPF  JUMBO ANJEER 500G       1125.0              1
# 3  order_LzsZKuPQrIFqhA         JAMUN 500G        400.0              1
# 4  order_LzsZKuPQrIFqhA     AVOCADOS 2 PCS        600.0              1
#
#    item payment amount  total payment amount currency payment status  \
# 0                385.0                2665.0      INR       captured
# 1               1155.0                2665.0      INR       captured
# 2               1125.0                2665.0      INR       captured
# 3                400.0                1915.0      INR         failed
# 4                600.0                1915.0      INR         failed
#
#            payment id         name                  email         phone  \
# 0  pay_Lzfdv0D4AnBTRT   Ritu Sinha  rituarchit2@gmail.com  919910159998
# 1  pay_Lzfdv0D4AnBTRT   Ritu Sinha  rituarchit2@gmail.com  919910159998
# 2  pay_Lzfdv0D4AnBTRT   Ritu Sinha  rituarchit2@gmail.com  919910159998
# 3  pay_Lzsa4eUYLbxAht  Nisha singh      anish24@gmail.com    9167612477
# 4  pay_Lzsa4eUYLbxAht  Nisha singh      anish24@gmail.com    9167612477
#
#                towers apartment apartment_no
# 0           Vivarea A    3602.0          NaN
# 1           Vivarea A    3602.0          NaN
# 2           Vivarea A    3602.0          NaN
# 3  Lodha World towers       NaN         5801
# 4  Lodha World towers       NaN         5801

# %%
combined_data.rename(columns={'item payment amount':'item payment amount(INR) '},inplace=True)

# %%
combined_data.describe()
# Out:
#        item amount  item quantity  item payment amount(INR)   \
# count   834.000000     834.000000                 834.000000
# mean    199.619904       1.169065                 217.678657
# std     269.014476       0.522210                 297.107625
# min      15.000000       1.000000                  15.000000
# 25%      38.000000       1.000000                  39.000000
# 50%      85.000000       1.000000                 100.000000
# 75%     200.000000       1.000000                 260.000000
# max    1450.000000       5.000000                2310.000000
#
#        total payment amount         phone
# count            834.000000  8.340000e+02
# mean            1286.033573  4.550878e+10
# std             1076.899956  1.775897e+11
# min              105.000000  2.223515e+09
# 25%              551.000000  9.717837e+09
# 50%              990.000000  9.820147e+09
# 75%             1730.000000  9.820605e+09
# max             6255.000000  9.199102e+11

# %%
combined_data_copy = combined_data.copy()

# %%
combined_data_copy
# Out:
#        payment page id                 payment page title  \
# 0    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 1    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 2    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 3    pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10
# 4    pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10
# ..                 ...                                ...
# 829  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 830  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 831  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 832  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 833  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
#
#             payment date              order_id                  item name  \
# 0    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF           MIXED SEEDS 250G
# 1    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF               WALNUTS 500G
# 2    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF          JUMBO ANJEER 500G
# 3    09/06/2023 20:53:00  order_LzsZKuPQrIFqhA                 JAMUN 500G
# 4    09/06/2023 20:53:00  order_LzsZKuPQrIFqhA             AVOCADOS 2 PCS
# ..                   ...                   ...                        ...
# 829  02/06/2023 13:05:14  order_Lwys2qrNfCncTf         HAPUS MANGOES 1DOZ
# 830  02/06/2023 13:05:14  order_Lwys2qrNfCncTf            POMEGRANATE 1KG
# 831  02/06/2023 13:05:14  order_Lwys2qrNfCncTf        IMPORTED APPLES 1KG
# 832  02/06/2023 13:05:14  order_Lwys2qrNfCncTf  MANDARIN MINI ORANGES 1KG
# 833  02/06/2023 13:05:14  order_Lwys2qrNfCncTf                   DELIVERY
#
#      item amount  item quantity  item payment amount(INR)   \
# 0          385.0              1                      385.0
# 1         1155.0              1                     1155.0
# 2         1125.0              1                     1125.0
# 3          400.0              1                      400.0
# 4          600.0              1                      600.0
# ..           ...            ...                        ...
# 829        950.0              1                      950.0
# 830        350.0              1                      350.0
# 831        380.0              1                      380.0
# 832        400.0              1                      400.0
# 833         15.0              1                       15.0
#
#      total payment amount currency payment status          payment id  \
# 0                  2665.0      INR       captured  pay_Lzfdv0D4AnBTRT
# 1                  2665.0      INR       captured  pay_Lzfdv0D4AnBTRT
# 2                  2665.0      INR       captured  pay_Lzfdv0D4AnBTRT
# 3                  1915.0      INR         failed  pay_Lzsa4eUYLbxAht
# 4                  1915.0      INR         failed  pay_Lzsa4eUYLbxAht
# ..                    ...      ...            ...                 ...
# 829                2295.0      INR       captured  pay_Lwys6fwwkJg9Ij
# 830                2295.0      INR       captured  pay_Lwys6fwwkJg9Ij
# 831                2295.0      INR       captured  pay_Lwys6fwwkJg9Ij
# 832                2295.0      INR       captured  pay_Lwys6fwwkJg9Ij
# 833                2295.0      INR       captured  pay_Lwys6fwwkJg9Ij
#
#             name                     email         phone              towers  \
# 0     Ritu Sinha     rituarchit2@gmail.com  919910159998           Vivarea A
# 1     Ritu Sinha     rituarchit2@gmail.com  919910159998           Vivarea A
# 2     Ritu Sinha     rituarchit2@gmail.com  919910159998           Vivarea A
# 3    Nisha singh         anish24@gmail.com    9167612477  Lodha World towers
# 4    Nisha singh         anish24@gmail.com    9167612477  Lodha World towers
# ..           ...                       ...           ...                 ...
# 829       Anubha  sawhney.anubha@gmail.com    9811190907           Vivarea C
# 830       Anubha  sawhney.anubha@gmail.com    9811190907           Vivarea C
# 831       Anubha  sawhney.anubha@gmail.com    9811190907           Vivarea C
# 832       Anubha  sawhney.anubha@gmail.com    9811190907           Vivarea C
# 833       Anubha  sawhney.anubha@gmail.com    9811190907           Vivarea C
#
#     apartment apartment_no
# 0      3602.0          NaN
# 1      3602.0          NaN
# 2      3602.0          NaN
# 3         NaN         5801
# 4         NaN         5801
# ..        ...          ...
# 829       NaN         1603
# 830       NaN         1603
# 831       NaN         1603
# 832       NaN         1603
# 833       NaN         1603
#
# [834 rows x 18 columns]

# %% [markdown]
# ### checking unique values and their count in each columns

# %%
combined_data_copy['payment page id'].nunique()
# Out:
# 21

# %%
combined_data_copy['payment page id'].value_counts()
# Out:
# pl_Luwm77aC8DpF68    71
# pl_LogYhuf1mBHscg    70
# pl_LxonlA4k4hCi7b    60
# pl_LlvPfuJNpJmwvK    56
# pl_Logay7jId0fQiS    55
# pl_LsBr8yg0Jk5lZE    55
# pl_LogbTyCHtE81ut    50
# pl_LtPH4of4dkHiCL    48
# pl_Llu9HXoCL2ryhf    45
# pl_Llu8WuhRSQ1Oca    45
# pl_LsBvOwSWzOzhGF    39
# pl_LlrhVVdlf0ZREH    36
# pl_Lw77t4FZvxried    33
# pl_LsC02WGhqpp2xv    30
# pl_LsBsvfkbuk04lf    30
# pl_LuwpdZn0NKaWd0    30
# pl_LxoqBxP7nVoyXT    28
# pl_LlxzivvCjRtGuG    26
# pl_LpoVGuUhKJzSae    14
# pl_Lpz6Jme2F2b9hm    10
# pl_LxopAaBcnfoeIR     3
# Name: payment page id, dtype: int64

# %%
combined_data_copy['payment page title'].nunique()
# Out:
# 21

# %%
combined_data_copy['payment page title'].value_counts()
# Out:
# FRUIT BASKET - MAY 29-31                  71
# FORM - 1 VEGETABLES MAY 16th              70
# FRUIT BASKET - JUNE 10                    60
# FRUIT BASKET - MAY 8th - 13th             56
# FORM - 2 VEGETABLES MAY 16th              55
# FRUIT BASKET - MAY 22-27                  55
# SALADS, EXOTIC VEGETABLES -\n MAY 16th    50
# FRUIT BASKET - MAY 24-27                  48
# FORM - 2 VEGETABLES MAY 9                 45
# FORM - 1 VEGETABLES MAY 9th               45
# FORM - 1 VEGETABLES MAY 23                39
# SALADS, EXOTIC VEGETABLES -\n MAY 9th     36
# FRUIT BASKET - JUNE3                      33
# FORM - 2 VEGETABLES MAY 23                30
# SALADS, EXOTIC VEGETABLES -\n MAY 23      30
# SALADS, EXOTIC VEGETABLES -\n MAY 30      30
# SALADS, EXOTIC VEGETABLES -\nJUNE 6       28
# DRYFRUITS, SEEDS, NUTS MAY - 12th         26
# FRUIT BASKET - MAY 15-20                  14
# DRYFRUITS, SEEDS, NUTS MAY - 18           10
# DRYFRUITS, SEEDS, NUTS JUNE 5 -10          3
# Name: payment page title, dtype: int64

# %%
combined_data_copy['order_id'].nunique()
# Out:
# 141

# %%
combined_data_copy['payment id'].nunique()
# Out:
# 145

# %%
combined_data_copy['item name'].nunique()
# Out:
# 107

# %%
combined_data_copy['item name'].value_counts()
# Out:
# DELIVERY                 99
# KOLKATTA LYCHEES 1KG     25
# AVOCADOS 2 PCS           22
# IMPORTED APPLES 1KG      22
# CHICKOO 1KG              18
#                          ..
# GIR KESAR MANGOES 5kg     1
# PINEAPPLE                 1
# KESAR MANGOES 5KG BOX     1
# JUMBO ANJEER 500G         1
# ITALIAN BASIL             1
# Name: item name, Length: 107, dtype: int64

# %%
combined_data_copy['currency'].nunique()
# Out:
# 1

# %%
combined_data_copy['payment status'].nunique()
# Out:
# 2

# %%
combined_data_copy['payment status'].value_counts()
# Out:
# captured    575
# failed      259
# Name: payment status, dtype: int64

# %%
combined_data_copy['towers'].nunique()
# Out:
# 22

# %%
combined_data_copy['towers'].value_counts()
# Out:
# Lodha Bellisimo       129
# Vivarea D             121
# Vivarea E             107
# Lodha Bellissimo       74
# Vivarea A              69
# Others                 62
# Vivarea C              46
# Lodha World towers     43
# World One              31
# Vivarea B              28
# Belvedere Court        24
# Lodha Park             17
# Parsi Colony           16
# World Towers           13
# Crescent Bay           13
# World Tower            12
# Othrs                   6
# Trump Towers            6
# Samudra Mahal           5
# Grand Paradi            5
# Springs                 4
# Lodha World Towers      3
# Name: towers, dtype: int64

# %%
combined_data_copy['name'].nunique()
# Out:
# 68

# %%
combined_data_copy['name'].value_counts()
# Out:
# Michelle Baptist    92
# Ruchi  Wahi         75
# Indrani Jafar       73
# kanchan             64
# Anubha              28
#                     ..
# Ushma kapoor         2
# Bhavna mehta         2
# Swaha sohm           2
# Preeti Rathod        2
# Harsha Bangari       2
# Name: name, Length: 68, dtype: int64

# %%
combined_data_copy['phone'].nunique()
# Out:
# 38

# %%
combined_data_copy['phone'].value_counts()
# Out:
# 9167612477      122
# 9820354560      101
# 9820605121       92
# 9820108861       79
# 9833951659       75
# 9717836663       54
# 7738186005       32
# 919910077228     30
# 9811190907       28
# 9820784333       20
# 9867707437       18
# 9920053079       18
# 9992886060       15
# 9820097357       13
# 7899905975       13
# 8691099365       11
# 8657873174       11
# 9820147372       11
# 2223514839        9
# 9820127289        8
# 9820077254        8
# 9820287616        7
# 9820196452        6
# 8879019419        6
# 9870410556        4
# 9920072620        4
# 9769635184        4
# 9821327984        4
# 9910077228        4
# 9833075700        4
# 9820038207        4
# 9819435281        3
# 9920931320        3
# 9987014963        3
# 9820275622        3
# 919910159998      3
# 9594970717        2
# 9833184197        2
# Name: phone, dtype: int64

# %%
combined_data_copy['item quantity'].value_counts()
# Out:
# 1    732
# 2     78
# 4     13
# 3     10
# 5      1
# Name: item quantity, dtype: int64

# %% [markdown]
# #### cheching null value count

# %%
combined_data_copy.isnull().sum()
# Out:
# payment page id                0
# payment page title             0
# payment date                   0
# order_id                       0
# item name                      0
# item amount                    0
# item quantity                  0
# item payment amount(INR)       0
# total payment amount           0
# currency                       0
# payment status                 0
# payment id                     0
# name                           0
# email                          0
# phone                          0
# towers                         0
# apartment                    795
# apartment_no                  39
# dtype: int64

# %% [markdown]
# #### Droping apartment-no ,apartment and currency column

# %%
combined_data_copy.drop(columns=['currency','apartment','apartment_no'],inplace=True)

# %%
(combined_data_copy['payment status'].value_counts()/len(combined_data_copy))*100
# Out:
# captured    68.944844
# failed      31.055156
# Name: payment status, dtype: float64

# %%
combined_data_payment_failed = combined_data_copy[combined_data_copy['payment status']=='failed']
combined_data_payment_completed = combined_data_copy[combined_data_copy['payment status']=='captured']

# %%
combined_data_payment_completed
# Out:
#        payment page id                 payment page title  \
# 0    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 1    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 2    pl_LxopAaBcnfoeIR  DRYFRUITS, SEEDS, NUTS JUNE 5 -10
# 7    pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10
# 8    pl_LxonlA4k4hCi7b             FRUIT BASKET - JUNE 10
# ..                 ...                                ...
# 829  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 830  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 831  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 832  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
# 833  pl_Lw77t4FZvxried               FRUIT BASKET - JUNE3
#
#             payment date              order_id                  item name  \
# 0    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF           MIXED SEEDS 250G
# 1    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF               WALNUTS 500G
# 2    09/06/2023 08:13:40  order_LzfdbQw8rMiwPF          JUMBO ANJEER 500G
# 7    10/06/2023 11:12:59  order_M07ENl4ODBEkc5                 PAPAYA 1PC
# 8    10/06/2023 11:12:59  order_M07ENl4ODBEkc5             AVOCADOS 2 PCS
# ..                   ...                   ...                        ...
# 829  02/06/2023 13:05:14  order_Lwys2qrNfCncTf         HAPUS MANGOES 1DOZ
# 830  02/06/2023 13:05:14  order_Lwys2qrNfCncTf            POMEGRANATE 1KG
# 831  02/06/2023 13:05:14  order_Lwys2qrNfCncTf        IMPORTED APPLES 1KG
# 832  02/06/2023 13:05:14  order_Lwys2qrNfCncTf  MANDARIN MINI ORANGES 1KG
# 833  02/06/2023 13:05:14  order_Lwys2qrNfCncTf                   DELIVERY
#
#      item amount  item quantity  item payment amount(INR)   \
# 0          385.0              1                      385.0
# 1         1155.0              1                     1155.0
# 2         1125.0              1                     1125.0
# 7          100.0              1                      100.0
# 8          600.0              1                      600.0
# ..           ...            ...                        ...
# 829        950.0              1                      950.0
# 830        350.0              1                      350.0
# 831        380.0              1                      380.0
# 832        400.0              1                      400.0
# 833         15.0              1                       15.0
#
#      total payment amount payment status          payment id  \
# 0                  2665.0       captured  pay_Lzfdv0D4AnBTRT
# 1                  2665.0       captured  pay_Lzfdv0D4AnBTRT
# 2                  2665.0       captured  pay_Lzfdv0D4AnBTRT
# 7                  1250.0       captured  pay_M07EUhoIlT9vNf
# 8                  1250.0       captured  pay_M07EUhoIlT9vNf
# ..                    ...            ...                 ...
# 829                2295.0       captured  pay_Lwys6fwwkJg9Ij
# 830                2295.0       captured  pay_Lwys6fwwkJg9Ij
# 831                2295.0       captured  pay_Lwys6fwwkJg9Ij
# 832                2295.0       captured  pay_Lwys6fwwkJg9Ij
# 833                2295.0       captured  pay_Lwys6fwwkJg9Ij
#
#                   name                     email         phone     towers
# 0           Ritu Sinha     rituarchit2@gmail.com  919910159998  Vivarea A
# 1           Ritu Sinha     rituarchit2@gmail.com  919910159998  Vivarea A
# 2           Ritu Sinha     rituarchit2@gmail.com  919910159998  Vivarea A
# 7    Tanvi Jain Patyal        tanvi.jn@gmail.com  919910077228  Vivarea E
# 8    Tanvi Jain Patyal        tanvi.jn@gmail.com  919910077228  Vivarea E
# ..                 ...                       ...           ...        ...
# 829             Anubha  sawhney.anubha@gmail.com    9811190907  Vivarea C
# 830             Anubha  sawhney.anubha@gmail.com    9811190907  Vivarea C
# 831             Anubha  sawhney.anubha@gmail.com    9811190907  Vivarea C
# 832             Anubha  sawhney.anubha@gmail.com    9811190907  Vivarea C
# 833             Anubha  sawhney.anubha@gmail.com    9811190907  Vivarea C
#
# [575 rows x 15 columns]

# %% [markdown]
# we can drop payment page id column and seggregte titles of item

# %%
combined_data_payment_completed.drop(columns=['payment page id'],inplace=True)

# %%
#removing payment id as we can get the desired information from orderid
combined_data_payment_completed.drop(columns=['payment id'],inplace=True)

# %%
#removing status as we only have successful payments now
combined_data_payment_completed.drop(columns=['payment status'],inplace=True)

# %%
dryfruits=combined_data_payment_completed['payment page title'].str.startswith('DRYFRUITS, SEEDS, NUTS')
combined_data_payment_completed.loc[dryfruits,'payment page title']='DRYFRUITS, SEEDS, NUTS'

fruits=combined_data_payment_completed['payment page title'].str.startswith('FRUIT BASKET')
combined_data_payment_completed.loc[fruits,'payment page title']='FRUIT BASKET'

exotic_vegies=combined_data_payment_completed['payment page title'].str.startswith('SALADS, EXOTIC VEGETABLES')
combined_data_payment_completed.loc[exotic_vegies,'payment page title']='SALADS, EXOTIC VEGETABLES'

vegies=combined_data_payment_completed['payment page title'].str.startswith('FORM')
combined_data_payment_completed.loc[vegies,'payment page title']='VEGETABLES'

# %%
#seggregating payment page title
combined_data_payment_completed['payment page title'].value_counts()
# Out:
# VEGETABLES                   234
# FRUIT BASKET                 212
# SALADS, EXOTIC VEGETABLES    114
# DRYFRUITS, SEEDS, NUTS        15
# Name: payment page title, dtype: int64

# %%
combined_data_payment_completed.columns
# Out:
# Index(['payment page title', 'payment date', 'order_id', 'item name',
#        'item amount', 'item quantity', 'item payment amount(INR) ',
#        'total payment amount', 'name', 'email', 'phone', 'towers'],
#       dtype='object')

# %%
combined_data_payment_completed['payment date'].value_counts()
# Out:
# 21/05/2023 17:16:26    15
# 15/05/2023 13:59:21    15
# 07/05/2023 22:35:03    14
# 28/05/2023 14:59:49    14
# 07/05/2023 22:36:33    13
#                        ..
# 15/05/2023 09:20:56     2
# 08/05/2023 10:29:06     2
# 07/05/2023 22:13:37     2
# 09/05/2023 15:54:21     2
# 17/05/2023 15:29:51     1
# Name: payment date, Length: 95, dtype: int64

# %%
combined_data_payment_completed['payment date']=combined_data_payment_completed['payment date'].astype(str)

# %%
combined_data_payment_completed['date']=combined_data_payment_completed['payment date'].str.split().str[0]

# %%
combined_data_payment_completed['time']=combined_data_payment_completed['payment date'].str.split().str[1]

# %%
combined_data_payment_completed['year']=combined_data_payment_completed['date'].str.split('/').str[2].astype(int)
combined_data_payment_completed['day']=combined_data_payment_completed['date'].str.split('/').str[0].astype(int)
combined_data_payment_completed['month']=combined_data_payment_completed['date'].str.split('/').str[1].astype(int)

# %%
combined_data_payment_completed['date'] = pd.to_datetime(combined_data_payment_completed[['year', 'month', 'day']])

# %%
combined_data_payment_completed['name'] = combined_data_payment_completed['name'].str.strip().str.lower()

# %%
combined_data_payment_completed['towers'] = combined_data_payment_completed['towers'].str.strip().str.lower()
combined_data_payment_completed['item name'] = combined_data_payment_completed['item name'].str.strip().str.lower()
combined_data_payment_completed['email'] = combined_data_payment_completed['email'].str.strip().str.lower()

# %%
print("number of days for which we are performing our analysis")
(combined_data_payment_completed['date'].max()-combined_data_payment_completed['date'].min())
# Out:
# number of days for which we are performing our analysis
# Timedelta('35 days 00:00:00')

# %%
df = pd.DataFrame(combined_data_payment_completed)
df_grouped = df.groupby('email')['name','phone'].first().reset_index()
df_grouped = df_grouped.sort_values(by="name", ascending=True)
display(df_grouped)
# Out:
#                           email               name         phone
# 1       aneeshamehra7@gmail.com      aneesha mehra    9820077254
# 19     sawhney.anubha@gmail.com             anubha    9811190907
# 3      archanaswami@hotmail.com      archana swami    9820147372
# 4       billimoriaash@gmail.com  ashish billimoria    9819435281
# 6         deepti.moga@gmail.com        deepti moga    9992886060
# 7         ekishnani@hotmail.com        ekta bhatia    9820784333
# 8      harsha.bangari@yahoo.com     harsha bangari    9833184197
# 2           ani.doley@gmail.com      indrani jafar    9820108861
# 9           jasmak999@yahoo.com      jasma kapadia    9820038207
# 18      samtani.kanchan@bcg.com            kanchan    9820354560
# 10       naina.sharma@gmail.com              naina    9867707437
# 11      neetu.vinayek@gmail.com      neetu vinayek    9820287616
# 12          noynadutt@gmail.com         noyna dutt    9920072620
# 13        padmasree.r@gmail.com          padmasree    9769635184
# 0      2014parulkumar@gmail.com        parul kumar    9717836663
# 14  payalmaheshwari@hotmail.com              payal    9820196452
# 15    rathod_preeti@yahoo.co.in      preeti rathod    9594970717
# 16           ricmchou@gmail.com    richa chourasia    7738186005
# 17        rituarchit2@gmail.com         ritu sinha  919910159998
# 28        wahiruchi80@gmail.com        ruchi  wahi    9833951659
# 20      shradhagoenka@gmail.com     shradha goenka    9987014963
# 21     shwethakallaje@gmail.com    shwetha kallaje    7899905975
# 22               simosh@mac.com     simeen oshidar    2223514839
# 5        dalalsmita@yahoo.co.in        smita dalal    9920931320
# 23            sonavid@gmail.com       sonavi desai    9820097357
# 24           tanvi.jn@gmail.com  tanvi jain patyal  919910077228
# 25           tmaskai5@gmail.com             trupti    9821327984
# 26         ushmasheth@gmail.com              ushma    9820275622
# 27         vijayd1108@gmail.com        vijay dubey    8879019419
# 29     yogesh.thakkar@gmail.com     yogesh thakkar    8691099365

# %%
merged_df = pd.merge(combined_data_payment_completed,df_grouped, on='email', how='left')
merged_df['name_x'].update(merged_df['name_y'])
merged_df['phone_x'].update(merged_df['phone_y'])
merged_df['name']=merged_df['name_x']
merged_df['phone']=merged_df['phone_x']
combined_data_payment_completed=merged_df.drop(columns=['name_x','name_y','phone_x','phone_y'])

# %%
print("Total number of item bought by individuals")
combined_data_payment_completed['name'].value_counts().reset_index(name='frequency')
# Out:
# Total number of item bought by individuals
#                 index  frequency
# 0             kanchan         96
# 1       indrani jafar         79
# 2         ruchi  wahi         72
# 3         parul kumar         54
# 4   tanvi jain patyal         34
# 5     richa chourasia         32
# 6              anubha         28
# 7         ekta bhatia         20
# 8               naina         18
# 9      simeen oshidar         17
# 10        deepti moga         15
# 11       sonavi desai         13
# 12    shwetha kallaje         13
# 13      archana swami         11
# 14     yogesh thakkar         11
# 15      aneesha mehra          8
# 16      neetu vinayek          7
# 17              payal          6
# 18        vijay dubey          6
# 19          padmasree          4
# 20             trupti          4
# 21      jasma kapadia          4
# 22         noyna dutt          4
# 23  ashish billimoria          3
# 24        smita dalal          3
# 25              ushma          3
# 26     shradha goenka          3
# 27         ritu sinha          3
# 28      preeti rathod          2
# 29     harsha bangari          2

# %%
combined_data_payment_completed['phone'].nunique()
# Out:
# 30

# %%
categories=combined_data_payment_completed['payment page title'].unique()
categories_sales=dict()
for category in categories:
    categories_sales[category]=combined_data_payment_completed[combined_data_payment_completed['payment page title']==category]['item payment amount(INR) '].sum()

df = pd.DataFrame(categories_sales.items(), columns=["Category Name", "Amount"])
df_sorted = df.sort_values(by="Amount", ascending=False)
display(df_sorted)
# Out:
#                Category Name   Amount
# 1               FRUIT BASKET  62195.0
# 0     DRYFRUITS, SEEDS, NUTS  16175.0
# 2  SALADS, EXOTIC VEGETABLES  13790.0
# 3                 VEGETABLES  13087.0

# %%
items_amount=combined_data_payment_completed.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
items_amount.sort_values(by='item payment amount(INR) ', ascending=False)
# Out:
#                item name  item payment amount(INR)   item quantity
# 38    hapus mangoes 1doz                    12000.0             11
# 1         avocados 2 pcs                     9200.0             15
# 41   imported apples 1kg                     5700.0             15
# 43            jamun 500g                     4780.0             13
# 49  kolkatta lychees 1kg                     4700.0              9
# ..                   ...                        ...            ...
# 11      broad beans 500g                       59.0              1
# 90       sweet corn 2 pc                       44.0              1
# 0     amaranth red bunch                       44.0              1
# 75   raw papaya 1pc 500g                       42.0              1
# 73     raw banana 500 gm                       40.0              1
#
# [99 rows x 3 columns]

# %%
# Sort the DataFrame by date in descending order
df_sorted = combined_data_payment_completed.sort_values(by='date', ascending=False)

# Drop duplicates based on email column, keeping the first occurrence (most recent date)
df_unique = df_sorted.drop_duplicates(subset='email', keep='first')

# Create the DataFrame with 'name', 'email', and 'most_recent_date' columns
df_most_recent = df_unique[['name', 'email', 'date']].rename(columns={'date': 'Most_recent_Purchase_date'})
current_date=combined_data_payment_completed['date'].max()
# Print the resulting DataFrame
df_most_recent['Number of days after Purchase']=current_date-df_most_recent['Most_recent_Purchase_date']
df_most_recent
# Out:
#                   name                        email Most_recent_Purchase_date  \
# 3    tanvi jain patyal           tanvi.jn@gmail.com                2023-06-10
# 0           ritu sinha        rituarchit2@gmail.com                2023-06-09
# 35              anubha     sawhney.anubha@gmail.com                2023-06-07
# 21               naina       naina.sharma@gmail.com                2023-06-07
# 50         deepti moga        deepti.moga@gmail.com                2023-06-05
# 67      simeen oshidar               simosh@mac.com                2023-06-05
# 57      harsha bangari     harsha.bangari@yahoo.com                2023-06-05
# 48         smita dalal       dalalsmita@yahoo.co.in                2023-06-05
# 42       indrani jafar          ani.doley@gmail.com                2023-06-05
# 543      jasma kapadia          jasmak999@yahoo.com                2023-06-04
# 8       shradha goenka      shradhagoenka@gmail.com                2023-06-04
# 34         parul kumar     2014parulkumar@gmail.com                2023-06-04
# 567    shwetha kallaje     shwethakallaje@gmail.com                2023-06-02
# 547        vijay dubey         vijayd1108@gmail.com                2023-05-31
# 552            kanchan      samtani.kanchan@bcg.com                2023-05-31
# 523        ruchi  wahi        wahiruchi80@gmail.com                2023-05-29
# 494      aneesha mehra      aneeshamehra7@gmail.com                2023-05-27
# 455      neetu vinayek      neetu.vinayek@gmail.com                2023-05-27
# 473              ushma         ushmasheth@gmail.com                2023-05-25
# 444             trupti           tmaskai5@gmail.com                2023-05-22
# 421       sonavi desai            sonavid@gmail.com                2023-05-21
# 415          padmasree        padmasree.r@gmail.com                2023-05-21
# 351     yogesh thakkar     yogesh.thakkar@gmail.com                2023-05-19
# 323    richa chourasia           ricmchou@gmail.com                2023-05-15
# 294              payal  payalmaheshwari@hotmail.com                2023-05-15
# 310      archana swami     archanaswami@hotmail.com                2023-05-14
# 100         noyna dutt          noynadutt@gmail.com                2023-05-09
# 116        ekta bhatia        ekishnani@hotmail.com                2023-05-08
# 190      preeti rathod    rathod_preeti@yahoo.co.in                2023-05-08
# 207  ashish billimoria      billimoriaash@gmail.com                2023-05-08
#
#     Number of days after Purchase
# 3                          0 days
# 0                          1 days
# 35                         3 days
# 21                         3 days
# 50                         5 days
# 67                         5 days
# 57                         5 days
# 48                         5 days
# 42                         5 days
# 543                        6 days
# 8                          6 days
# 34                         6 days
# 567                        8 days
# 547                       10 days
# 552                       10 days
# 523                       12 days
# 494                       14 days
# 455                       14 days
# 473                       16 days
# 444                       19 days
# 421                       20 days
# 415                       20 days
# 351                       22 days
# 323                       26 days
# 294                       26 days
# 310                       27 days
# 100                       32 days
# 116                       33 days
# 190                       33 days
# 207                       33 days

# %%
df_freq=df_most_recent.groupby('Most_recent_Purchase_date')['name'].size().reset_index()
# Create a scatter plot or line plot
plt.figure(figsize=(10, 6)) 

# Line plot
plt.plot(df_freq['Most_recent_Purchase_date'], df_freq['name'], marker='o')
plt.xlabel('Date')
plt.ylabel('Total Frequency')
plt.xticks(rotation=45)
plt.title('Customers most recent purchase by Date')
# Out:
# Text(0.5, 1.0, 'Customers most recent purchase by Date')

# %%
# Sort the DataFrame by date in descending order
df_sorted = combined_data_payment_completed.sort_values(by='date', ascending=True)

# Drop duplicates based on email column, keeping the first occurrence (most recent date)
df_unique = df_sorted.drop_duplicates(subset='email', keep='first')

# Create the DataFrame with 'name', 'email', and 'most_recent_date' columns
df_oldest_date = df_unique[['name', 'email', 'date']].rename(columns={'date': 'oldest_Purchase_date'})
# Print the resulting DataFrame
df_oldest_date
# Out:
#                   name                        email oldest_Purchase_date
# 149        parul kumar     2014parulkumar@gmail.com           2023-05-06
# 145      archana swami     archanaswami@hotmail.com           2023-05-07
# 123        ruchi  wahi        wahiruchi80@gmail.com           2023-05-07
# 144            kanchan      samtani.kanchan@bcg.com           2023-05-07
# 195      indrani jafar          ani.doley@gmail.com           2023-05-08
# 110        ekta bhatia        ekishnani@hotmail.com           2023-05-08
# 207  ashish billimoria      billimoriaash@gmail.com           2023-05-08
# 190      preeti rathod    rathod_preeti@yahoo.co.in           2023-05-08
# 209             anubha     sawhney.anubha@gmail.com           2023-05-09
# 101         noyna dutt          noynadutt@gmail.com           2023-05-09
# 90     richa chourasia           ricmchou@gmail.com           2023-05-10
# 72        sonavi desai            sonavid@gmail.com           2023-05-12
# 340     simeen oshidar               simosh@mac.com           2023-05-14
# 295              payal  payalmaheshwari@hotmail.com           2023-05-15
# 349              naina       naina.sharma@gmail.com           2023-05-18
# 356     yogesh thakkar     yogesh.thakkar@gmail.com           2023-05-19
# 431    shwetha kallaje     shwethakallaje@gmail.com           2023-05-21
# 415          padmasree        padmasree.r@gmail.com           2023-05-21
# 444             trupti           tmaskai5@gmail.com           2023-05-22
# 470      aneesha mehra      aneeshamehra7@gmail.com           2023-05-24
# 486  tanvi jain patyal           tanvi.jn@gmail.com           2023-05-24
# 473              ushma         ushmasheth@gmail.com           2023-05-25
# 461      neetu vinayek      neetu.vinayek@gmail.com           2023-05-27
# 508        deepti moga        deepti.moga@gmail.com           2023-05-30
# 551        vijay dubey         vijayd1108@gmail.com           2023-05-31
# 542      jasma kapadia          jasmak999@yahoo.com           2023-06-04
# 10      shradha goenka      shradhagoenka@gmail.com           2023-06-04
# 46         smita dalal       dalalsmita@yahoo.co.in           2023-06-05
# 58      harsha bangari     harsha.bangari@yahoo.com           2023-06-05
# 2           ritu sinha        rituarchit2@gmail.com           2023-06-09

# %%
name_amount=combined_data_payment_completed.groupby('name')['item payment amount(INR) '].sum().reset_index()
name_amount.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#                  name  item payment amount(INR)
# 7       indrani jafar                    12825.0
# 1              anubha                    11435.0
# 9             kanchan                    10824.0
# 29     yogesh thakkar                     8350.0
# 14        parul kumar                     7660.0
# 25  tanvi jain patyal                     6810.0
# 19        ruchi  wahi                     6501.0
# 10              naina                     5850.0
# 24       sonavi desai                     5450.0
# 17    richa chourasia                     3092.0
# 21    shwetha kallaje                     3020.0
# 11      neetu vinayek                     2850.0
# 18         ritu sinha                     2665.0
# 22     simeen oshidar                     2650.0
# 0       aneesha mehra                     2425.0
# 12         noyna dutt                     2035.0
# 4         deepti moga                     1905.0
# 20     shradha goenka                     1565.0
# 28        vijay dubey                     1510.0
# 13          padmasree                     1395.0
# 8       jasma kapadia                      930.0
# 5         ekta bhatia                      881.0
# 27              ushma                      765.0
# 2       archana swami                      537.0
# 26             trupti                      300.0
# 15              payal                      297.0
# 23        smita dalal                      235.0
# 3   ashish billimoria                      235.0
# 16      preeti rathod                      125.0
# 6      harsha bangari                      125.0

# %%
# Group data by 'name' and calculate the number of unique dates for each group
unique_days = combined_data_payment_completed.groupby('name')['date'].nunique().reset_index()

# Rename the column to 'unique_days'
unique_days=unique_days.sort_values(by='date',ascending=False)

unique_days = unique_days.rename(columns={'date': 'Number of times ordered this month','name':'Customer Name'})



unique_days
# Out:
#         Customer Name  Number of times ordered this month
# 7       indrani jafar                                  10
# 19        ruchi  wahi                                   7
# 1              anubha                                   6
# 14        parul kumar                                   6
# 9             kanchan                                   5
# 25  tanvi jain patyal                                   4
# 24       sonavi desai                                   2
# 17    richa chourasia                                   2
# 21    shwetha kallaje                                   2
# 22     simeen oshidar                                   2
# 0       aneesha mehra                                   2
# 10              naina                                   2
# 4         deepti moga                                   2
# 2       archana swami                                   2
# 23        smita dalal                                   1
# 26             trupti                                   1
# 27              ushma                                   1
# 28        vijay dubey                                   1
# 20     shradha goenka                                   1
# 15              payal                                   1
# 18         ritu sinha                                   1
# 16      preeti rathod                                   1
# 13          padmasree                                   1
# 12         noyna dutt                                   1
# 11      neetu vinayek                                   1
# 8       jasma kapadia                                   1
# 6      harsha bangari                                   1
# 5         ekta bhatia                                   1
# 3   ashish billimoria                                   1
# 29     yogesh thakkar                                   1

# %%
df_sorted_amount=df_sorted_amount.sort_values(by='Customer Name')
unique_days=unique_days.sort_values(by='Customer Name')

merged_df = pd.merge(unique_days,df_sorted_amount, on='Customer Name', how='left')

merged_df['amount per order']=merged_df['Amount']//merged_df['Number of times ordered this month']
merged_df
# Out:
#         Customer Name  Number of times ordered this month   Amount  \
# 0       aneesha mehra                                   2   2425.0
# 1              anubha                                   6  11435.0
# 2       archana swami                                   2    537.0
# 3   ashish billimoria                                   1    235.0
# 4         deepti moga                                   2   1905.0
# 5         ekta bhatia                                   1    881.0
# 6      harsha bangari                                   1    125.0
# 7       indrani jafar                                  10  12825.0
# 8       jasma kapadia                                   1    930.0
# 9             kanchan                                   5  10824.0
# 10              naina                                   2   5850.0
# 11      neetu vinayek                                   1   2850.0
# 12         noyna dutt                                   1   2035.0
# 13          padmasree                                   1   1395.0
# 14        parul kumar                                   6   7660.0
# 15              payal                                   1    297.0
# 16      preeti rathod                                   1    125.0
# 17    richa chourasia                                   2   3092.0
# 18         ritu sinha                                   1   2665.0
# 19        ruchi  wahi                                   7   6501.0
# 20     shradha goenka                                   1   1565.0
# 21    shwetha kallaje                                   2   3020.0
# 22     simeen oshidar                                   2   2650.0
# 23        smita dalal                                   1    235.0
# 24       sonavi desai                                   2   5450.0
# 25  tanvi jain patyal                                   4   6810.0
# 26             trupti                                   1    300.0
# 27              ushma                                   1    765.0
# 28        vijay dubey                                   1   1510.0
# 29     yogesh thakkar                                   1   8350.0
#
#     amount per order
# 0             1212.0
# 1             1905.0
# 2              268.0
# 3              235.0
# 4              952.0
# 5              881.0
# 6              125.0
# 7             1282.0
# 8              930.0
# 9             2164.0
# 10            2925.0
# 11            2850.0
# 12            2035.0
# 13            1395.0
# 14            1276.0
# 15             297.0
# 16             125.0
# 17            1546.0
# 18            2665.0
# 19             928.0
# 20            1565.0
# 21            1510.0
# 22            1325.0
# 23             235.0
# 24            2725.0
# 25            1702.0
# 26             300.0
# 27             765.0
# 28            1510.0
# 29            8350.0

# %% [markdown]
# ### visualization

# %%
date_amount=combined_data_payment_completed.groupby('date')['item payment amount(INR) '].sum().reset_index()
date_amount.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#          date  item payment amount(INR)
# 13 2023-05-21                     8979.0
# 12 2023-05-19                     8350.0
# 9  2023-05-15                     5986.0
# 4  2023-05-10                     5875.0
# 14 2023-05-22                     5577.0
# 23 2023-06-04                     5325.0
# 21 2023-05-31                     4780.0
# 17 2023-05-27                     4710.0
# 3  2023-05-09                     4635.0
# 18 2023-05-28                     4495.0
# 7  2023-05-13                     4269.0
# 26 2023-06-07                     4250.0
# 15 2023-05-24                     3820.0
# 1  2023-05-07                     3552.0
# 22 2023-06-02                     3445.0
# 16 2023-05-25                     3430.0
# 24 2023-06-05                     2955.0
# 11 2023-05-18                     2900.0
# 2  2023-05-08                     2808.0
# 27 2023-06-09                     2665.0
# 6  2023-05-12                     2110.0
# 8  2023-05-14                     1719.0
# 19 2023-05-29                     1630.0
# 5  2023-05-11                     1495.0
# 25 2023-06-06                     1250.0
# 28 2023-06-10                     1250.0
# 20 2023-05-30                     1250.0
# 10 2023-05-17                     1155.0
# 0  2023-05-06                      582.0

# %%
daily_sales = combined_data_payment_completed.groupby('date')['item payment amount(INR) '].sum().reset_index()


matplotlib.rcParams['figure.figsize']=(12,6)
plt.plot(daily_sales['date'], daily_sales['item payment amount(INR) '])
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Trends of Sales per Day')
plt.xticks(rotation=45)
plt.show()

# %%
combined_data_payment_completed['date']
# Out:
# 0     2023-06-09
# 1     2023-06-09
# 2     2023-06-09
# 3     2023-06-10
# 4     2023-06-10
#          ...
# 570   2023-06-02
# 571   2023-06-02
# 572   2023-06-02
# 573   2023-06-02
# 574   2023-06-02
# Name: date, Length: 575, dtype: datetime64[ns]

# %%
daily_category_sales = combined_data_payment_completed.groupby(['date', 'payment page title'])['item payment amount(INR) '].sum().reset_index()

pivot_data =daily_category_sales.pivot(index='date', columns='payment page title', values='item payment amount(INR) ')

plt.figure(figsize=(20, 30))
pivot_data.plot(kind='bar', stacked=False)
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Sales per Day by Categories')
plt.legend()
plt.show()

# %% [markdown]
# this trend shows that on 21 june sales where heighest and fruit baskets where sold the most

# %%
daily_category_sales = combined_data_payment_completed.groupby(['date', 'payment page title'])['item quantity'].sum().reset_index()

pivot_data =daily_category_sales.pivot(index='date', columns='payment page title', values='item quantity')

plt.figure(figsize=(20, 30))
pivot_data.plot(kind='bar', stacked=False)
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Sales per Day by Categories')
plt.legend()
plt.show()

# %% [markdown]
# This trend shows that on 15 june vegetables where sold in heighest quantity

# %% [markdown]
# ### Dryfruits

# %%
pd.set_option('display.max_colwidth', 200)

# %%
dryfruits=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='DRYFRUITS, SEEDS, NUTS']
dryfruits_grouped=dryfruits.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

# %%
dryfruits_unique_names=dryfruits.groupby('item name')['name'].unique().reset_index()

dryfruits_unique=dryfruits.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(dryfruits_unique,dryfruits_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,dryfruits_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount(INR) ','item quantity':'item sales quantity'})
merged_df
# Out:
#                    item name  buyers count  sales amount(INR)   \
# 0               cashews 500g             1               820.0
# 1         golden rasins 500g             1               500.0
# 2            honey awla 500g             1               360.0
# 3          jumbo anjeer 500g             1              1125.0
# 4               makhana 250g             1               670.0
# 5           mixed seeds 250g             1               385.0
# 6             pine nuts 100g             1              1380.0
# 7       premium almonds 500g             1              1800.0
# 8   premium jumbo dates 500g             1               815.0
# 9          salted pista 500g             2              2900.0
# 10           soft dates 500g             1               800.0
# 11              walnuts 500g             3              4620.0
#
#     item sales quantity                                buyers Name
# 0                     1                           [yogesh thakkar]
# 1                     1                           [yogesh thakkar]
# 2                     1                           [yogesh thakkar]
# 3                     1                               [ritu sinha]
# 4                     2                            [indrani jafar]
# 5                     1                               [ritu sinha]
# 6                     2                            [indrani jafar]
# 7                     2                                   [anubha]
# 8                     1                           [yogesh thakkar]
# 9                     2            [indrani jafar, yogesh thakkar]
# 10                    2                                   [anubha]
# 11                    4  [ritu sinha, parul kumar, yogesh thakkar]

# %% [markdown]
# Table shows information regarding dry fruits categories item name,buyers count,sales amount,item sales quantity,buyers Name

# %%
dryfruit_date=dryfruits.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_dryfruits=dryfruits.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(dryfruit_date,unique_dryfruits, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#         date  item payment amount(INR)   \
# 3 2023-05-19                     6255.0
# 1 2023-05-10                     3500.0
# 4 2023-06-09                     2665.0
# 0 2023-05-09                     2600.0
# 2 2023-05-17                     1155.0
#
#                                                                                                         item name
# 3  [premium jumbo dates 500g, golden rasins 500g, walnuts 500g, honey awla 500g, salted pista 500g, cashews 500g]
# 1                                                               [makhana 250g, salted pista 500g, pine nuts 100g]
# 4                                                             [mixed seeds 250g, walnuts 500g, jumbo anjeer 500g]
# 0                                                                         [premium almonds 500g, soft dates 500g]
# 2                                                                                                  [walnuts 500g]

# %% [markdown]
# Dryfruits sales this month

# %% [markdown]
# ### Fruits

# %%
fruits=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='FRUIT BASKET']
fruits_grouped=fruits.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

fruits_unique_names=fruits.groupby('item name')['name'].unique().reset_index()

fruits_unique=fruits.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(fruits_unique,fruits_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,fruits_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df
# Out:
#                     item name  buyers count  sales amount  \
# 0              avocados 2 pcs             8        7970.0
# 1           blueberries 2 box             4        2200.0
# 2                 chickoo 1kg            10        2520.0
# 3                    delivery            20         585.0
# 4       elaichi banana 1dozen             7        1320.0
# 5                   guava 1kg             2         370.0
# 6          hapus mangoes 1doz             8       12000.0
# 7         imported apples 1kg             7        5700.0
# 8                  jamun 500g             6        4780.0
# 9       kesar mangoes 5kg box             1        1000.0
# 10                   kiwi box             6        2400.0
# 11       kolkatta lychees 1kg             7        4700.0
# 12  mandarin mini oranges 1kg             4        2550.0
# 13          mosumbi local 1kg             4         825.0
# 14              muskmelon 1pc             8        1620.0
# 15                 papaya 1pc             8        1300.0
# 16         payri mangoes 1doz             1        1150.0
# 17          peach indian 500g             5        1200.0
# 18                   pear 1kg             4        1200.0
# 19                  pineapple             1         165.0
# 20            pomegranate 1kg             4        3500.0
# 21       regular banana 1 doz             3         480.0
# 22         turkey cherry 500g             1         800.0
# 23                 watermelon             7        1860.0
#
#     item sales quantity  \
# 0                    13
# 1                     4
# 2                    14
# 3                    39
# 4                    11
# 5                     2
# 6                    11
# 7                    15
# 8                    13
# 9                     1
# 10                   12
# 11                    9
# 12                    7
# 13                    5
# 14                   12
# 15                   13
# 16                    1
# 17                    6
# 18                    4
# 19                    1
# 20                   10
# 21                    4
# 22                    1
# 23                   12
#
#                                                                                                                                                                                                 buyers Name
# 0                                                                                                 [tanvi jain patyal, naina, indrani jafar, richa chourasia, noyna dutt, padmasree, neetu vinayek, kanchan]
# 1                                                                                                                                                     [shradha goenka, aneesha mehra, ushma, jasma kapadia]
# 2                                                                  [naina, parul kumar, kanchan, ruchi  wahi, richa chourasia, yogesh thakkar, padmasree, sonavi desai, tanvi jain patyal, shwetha kallaje]
# 3   [tanvi jain patyal, shradha goenka, naina, indrani jafar, parul kumar, anubha, sonavi desai, kanchan, ruchi  wahi, richa chourasia, noyna dutt, yogesh thakkar, padmasree, shwetha kallaje, neetu vi...
# 4                                                                                                        [indrani jafar, parul kumar, richa chourasia, sonavi desai, shwetha kallaje, vijay dubey, kanchan]
# 5                                                                                                                                                                              [aneesha mehra, parul kumar]
# 6                                                                                                    [naina, sonavi desai, noyna dutt, yogesh thakkar, anubha, shwetha kallaje, neetu vinayek, parul kumar]
# 7                                                                                                               [anubha, sonavi desai, shwetha kallaje, parul kumar, ruchi  wahi, deepti moga, vijay dubey]
# 8                                                                                                                    [tanvi jain patyal, indrani jafar, parul kumar, neetu vinayek, aneesha mehra, kanchan]
# 9                                                                                                                                                                                          [shradha goenka]
# 10                                                                                                                        [indrani jafar, anubha, naina, tanvi jain patyal, jasma kapadia, shwetha kallaje]
# 11                                                                                                                     [naina, padmasree, anubha, neetu vinayek, aneesha mehra, tanvi jain patyal, kanchan]
# 12                                                                                                                                                  [anubha, sonavi desai, richa chourasia, yogesh thakkar]
# 13                                                                                                                                                  [sonavi desai, deepti moga, jasma kapadia, vijay dubey]
# 14                                                                                              [tanvi jain patyal, naina, ruchi  wahi, noyna dutt, neetu vinayek, parul kumar, indrani jafar, deepti moga]
# 15                                                                                           [tanvi jain patyal, naina, indrani jafar, parul kumar, ruchi  wahi, shwetha kallaje, deepti moga, vijay dubey]
# 16                                                                                                                                                                                                [kanchan]
# 17                                                                                                                                    [neetu vinayek, ushma, parul kumar, tanvi jain patyal, indrani jafar]
# 18                                                                                                                                                      [kanchan, indrani jafar, sonavi desai, deepti moga]
# 19                                                                                                                                                                                        [richa chourasia]
# 20                                                                                                                                                             [naina, anubha, yogesh thakkar, vijay dubey]
# 21                                                                                                                                                                        [naina, kanchan, richa chourasia]
# 22                                                                                                                                                                                            [parul kumar]
# 23                                                                                                         [anubha, parul kumar, ruchi  wahi, richa chourasia, indrani jafar, shwetha kallaje, deepti moga]

# %%
fruits_date=fruits.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_fruits=fruits.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(fruits_date,unique_fruits, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#          date  item payment amount(INR)   \
# 7  2023-05-21                     6605.0
# 17 2023-06-04                     5325.0
# 15 2023-05-31                     4780.0
# 11 2023-05-27                     4710.0
# 19 2023-06-07                     4250.0
# 9  2023-05-24                     3820.0
# 16 2023-06-02                     3445.0
# 10 2023-05-25                     3430.0
# 4  2023-05-13                     3225.0
# 5  2023-05-18                     2900.0
# 8  2023-05-22                     2800.0
# 1  2023-05-10                     2375.0
# 12 2023-05-28                     2295.0
# 3  2023-05-12                     2110.0
# 6  2023-05-19                     2095.0
# 0  2023-05-09                     2035.0
# 2  2023-05-11                     1495.0
# 14 2023-05-30                     1250.0
# 18 2023-06-06                     1250.0
# 20 2023-06-10                     1250.0
# 13 2023-05-29                      750.0
#
#                                                                                                                                                                                                   item name
# 7   [delivery, avocados 2 pcs, chickoo 1kg, kolkatta lychees 1kg, pear 1kg, mosumbi local 1kg, imported apples 1kg, mandarin mini oranges 1kg, hapus mangoes 1doz, elaichi banana 1dozen, watermelon, pa...
# 17                        [blueberries 2 box, kesar mangoes 5kg box, delivery, avocados 2 pcs, jamun 500g, papaya 1pc, elaichi banana 1dozen, turkey cherry 500g, chickoo 1kg, mosumbi local 1kg, kiwi box]
# 15                                                 [delivery, elaichi banana 1dozen, papaya 1pc, imported apples 1kg, mosumbi local 1kg, pomegranate 1kg, jamun 500g, avocados 2 pcs, kolkatta lychees 1kg]
# 11                                       [muskmelon 1pc, jamun 500g, avocados 2 pcs, hapus mangoes 1doz, peach indian 500g, delivery, kolkatta lychees 1kg, pomegranate 1kg, imported apples 1kg, kiwi box]
# 19  [muskmelon 1pc, pomegranate 1kg, kolkatta lychees 1kg, delivery, hapus mangoes 1doz, chickoo 1kg, avocados 2 pcs, papaya 1pc, regular banana 1 doz, watermelon, mandarin mini oranges 1kg, imported ...
# 9                                                [blueberries 2 box, delivery, jamun 500g, guava 1kg, kolkatta lychees 1kg, avocados 2 pcs, kiwi box, peach indian 500g, papaya 1pc, elaichi banana 1dozen]
# 16                                    [chickoo 1kg, kiwi box, imported apples 1kg, elaichi banana 1dozen, papaya 1pc, watermelon, delivery, hapus mangoes 1doz, pomegranate 1kg, mandarin mini oranges 1kg]
# 10                                                 [peach indian 500g, delivery, blueberries 2 box, muskmelon 1pc, jamun 500g, chickoo 1kg, guava 1kg, imported apples 1kg, watermelon, hapus mangoes 1doz]
# 4                                                                                  [delivery, regular banana 1 doz, payri mangoes 1doz, chickoo 1kg, pear 1kg, watermelon, elaichi banana 1dozen, kiwi box]
# 5                                                                   [chickoo 1kg, avocados 2 pcs, pomegranate 1kg, papaya 1pc, regular banana 1 doz, kiwi box, hapus mangoes 1doz, delivery, muskmelon 1pc]
# 8                                                                                          [watermelon, delivery, kolkatta lychees 1kg, pomegranate 1kg, hapus mangoes 1doz, kiwi box, imported apples 1kg]
# 1                                         [chickoo 1kg, watermelon, papaya 1pc, delivery, muskmelon 1pc, regular banana 1 doz, avocados 2 pcs, pineapple, mandarin mini oranges 1kg, elaichi banana 1dozen]
# 12                                                                             [chickoo 1kg, watermelon, imported apples 1kg, delivery, muskmelon 1pc, kolkatta lychees 1kg, peach indian 500g, jamun 500g]
# 3                                                                                                         [mosumbi local 1kg, mandarin mini oranges 1kg, delivery, imported apples 1kg, hapus mangoes 1doz]
# 6                                                                                                                   [mandarin mini oranges 1kg, hapus mangoes 1doz, chickoo 1kg, pomegranate 1kg, delivery]
# 0                                                                                                                                             [delivery, avocados 2 pcs, hapus mangoes 1doz, muskmelon 1pc]
# 2                                                                                                                                                [delivery, pomegranate 1kg, imported apples 1kg, kiwi box]
# 14                                                                                                      [papaya 1pc, delivery, mosumbi local 1kg, watermelon, muskmelon 1pc, imported apples 1kg, pear 1kg]
# 18                                                                                                                                        [jamun 500g, avocados 2 pcs, papaya 1pc, muskmelon 1pc, delivery]
# 20                                                                                                                                        [papaya 1pc, avocados 2 pcs, jamun 500g, muskmelon 1pc, delivery]
# 13                                                                                                                                                          [muskmelon 1pc, kiwi box, jamun 500g, delivery]

# %% [markdown]
# ### Vegetables

# %%
Vegetables=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='VEGETABLES']
Vegetables_grouped=Vegetables.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

Vegetables_unique_names=Vegetables.groupby('item name')['name'].unique().reset_index()

Vegetables_unique=Vegetables.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(Vegetables_unique,Vegetables_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,Vegetables_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df
# Out:
#                       item name  buyers count  sales amount  \
# 0            amaranth red bunch             1          44.0
# 1                 beetroot 500g             2         138.0
# 2             bitter gourd 500g             3         172.0
# 3                brinjal bharta             4         157.0
# 4   brinjal stripes kateri 500g             1          80.0
# 5              broad beans 500g             1          59.0
# 6                       cabbage             3         132.0
# 7              carrot ooty 500g             7         455.0
# 8                   cauliflower             6         510.0
# 9             chilli bhaji 250g             2          60.0
# 10          cucumber white 500g             2         128.0
# 11                 curry leaves             3         180.0
# 12                dhaniya bunch             7         682.0
# 13              drumsticks 250g             3         148.0
# 14                        dudhi             5         322.0
# 15            french beans 500g             6         628.0
# 16                  garlic 200g             5         434.0
# 17                   gavar 500g             1         104.0
# 18                ginger 250 gm             5         689.0
# 19          green capsicum 500g             4         318.0
# 20          green chilli 100 gm             2          92.0
# 21         kheera cucumber 500g             4         302.0
# 22           ladies finger 250g             5         698.0
# 23                   lemon 200g             5        1000.0
# 24                  methi bunch             6         327.0
# 25                   mint bunch             3         138.0
# 26                   onions 1kg             5         668.0
# 27                  palak bunch             6         945.0
# 28                  parwal 250g             2         202.0
# 29                 potatoes 1kg             5         752.0
# 30             pumpkin 500gm pc             5         308.0
# 31            raw banana 500 gm             1          40.0
# 32               raw mango 500g             3         118.0
# 33          raw papaya 1pc 500g             1          42.0
# 34             ridge gourd 500g             2         158.0
# 35           sambar onions 500g             1         114.0
# 36            sponge gourd 300g             2         107.0
# 37              sweet corn 2 pc             1          44.0
# 38            sweet potato 500g             3         236.0
# 39                  tendli 500g             2         212.0
# 40                   tinda 500g             3         176.0
# 41                 tomatoes 1kg             6         968.0
#
#     item sales quantity  \
# 0                     1
# 1                     4
# 2                     4
# 3                     4
# 4                     2
# 5                     1
# 6                     4
# 7                    12
# 8                    10
# 9                     2
# 10                    4
# 11                    8
# 12                   18
# 13                    5
# 14                    9
# 15                   10
# 16                   13
# 17                    2
# 18                   14
# 19                    7
# 20                    4
# 21                    9
# 22                   23
# 23                   15
# 24                    8
# 25                    5
# 26                   19
# 27                   25
# 28                    5
# 29                   20
# 30                    8
# 31                    1
# 32                    3
# 33                    1
# 34                    3
# 35                    2
# 36                    3
# 37                    1
# 38                    6
# 39                    4
# 40                    4
# 41                   24
#
#                                                                                         buyers Name
# 0                                                                                 [richa chourasia]
# 1                                                                            [ekta bhatia, kanchan]
# 2                                                               [ekta bhatia, kanchan, ruchi  wahi]
# 3                                                [parul kumar, payal, archana swami, indrani jafar]
# 4                                                                                     [ruchi  wahi]
# 5                                                                                   [archana swami]
# 6                                                               [kanchan, parul kumar, ruchi  wahi]
# 7   [ekta bhatia, parul kumar, kanchan, archana swami, ruchi  wahi, indrani jafar, richa chourasia]
# 8                [ruchi  wahi, indrani jafar, ekta bhatia, kanchan, richa chourasia, archana swami]
# 9                                                                            [ruchi  wahi, kanchan]
# 10                                                                           [ekta bhatia, kanchan]
# 11                                                          [ekta bhatia, kanchan, richa chourasia]
# 12  [ekta bhatia, parul kumar, ruchi  wahi, kanchan, archana swami, indrani jafar, richa chourasia]
# 13                                                              [ekta bhatia, kanchan, parul kumar]
# 14                                        [ekta bhatia, kanchan, payal, ruchi  wahi, indrani jafar]
# 15                         [ruchi  wahi, ekta bhatia, kanchan, payal, archana swami, indrani jafar]
# 16                                [ekta bhatia, parul kumar, ruchi  wahi, kanchan, richa chourasia]
# 17                                                                                        [kanchan]
# 18                                  [ekta bhatia, parul kumar, ruchi  wahi, kanchan, indrani jafar]
# 19                                               [indrani jafar, kanchan, parul kumar, ruchi  wahi]
# 20                                                                         [kanchan, indrani jafar]
# 21                                                 [parul kumar, payal, ruchi  wahi, archana swami]
# 22                                  [parul kumar, ruchi  wahi, indrani jafar, ekta bhatia, kanchan]
# 23                                  [ekta bhatia, parul kumar, ruchi  wahi, kanchan, indrani jafar]
# 24                 [ekta bhatia, kanchan, archana swami, parul kumar, ruchi  wahi, richa chourasia]
# 25                                                          [ruchi  wahi, kanchan, richa chourasia]
# 26                                [parul kumar, ekta bhatia, kanchan, richa chourasia, ruchi  wahi]
# 27                 [ekta bhatia, parul kumar, ruchi  wahi, kanchan, archana swami, richa chourasia]
# 28                                                                     [ruchi  wahi, indrani jafar]
# 29                                [parul kumar, ekta bhatia, kanchan, richa chourasia, ruchi  wahi]
# 30                              [ruchi  wahi, parul kumar, indrani jafar, richa chourasia, kanchan]
# 31                                                                                  [indrani jafar]
# 32                                                          [parul kumar, kanchan, richa chourasia]
# 33                                                                                  [indrani jafar]
# 34                                                                           [ekta bhatia, kanchan]
# 35                                                                                        [kanchan]
# 36                                                                       [kanchan, richa chourasia]
# 37                                                                                [richa chourasia]
# 38                                                                [kanchan, richa chourasia, payal]
# 39                                                                           [ruchi  wahi, kanchan]
# 40                                                                [parul kumar, payal, ruchi  wahi]
# 41                 [parul kumar, indrani jafar, ekta bhatia, kanchan, richa chourasia, ruchi  wahi]

# %%
Vegetables_date=Vegetables.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_Vegetables=Vegetables.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(Vegetables_date,unique_Vegetables, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#         date  item payment amount(INR)   \
# 5 2023-05-15                     4421.0
# 1 2023-05-07                     2542.0
# 6 2023-05-21                     2374.0
# 2 2023-05-08                     1103.0
# 7 2023-05-22                      852.0
# 3 2023-05-13                      784.0
# 0 2023-05-06                      582.0
# 4 2023-05-14                      429.0
#
#                                                                                                                                                                                                  item name
# 5  [carrot ooty 500g, curry leaves, mint bunch, methi bunch, garlic 200g, ginger 250 gm, green chilli 100 gm, sambar onions 500g, beetroot 500g, lemon 200g, palak bunch, dhaniya bunch, pumpkin 500gm ...
# 1  [garlic 200g, palak bunch, mint bunch, pumpkin 500gm pc, chilli bhaji 250g, dhaniya bunch, ginger 250 gm, lemon 200g, sambar onions 500g, sponge gourd 300g, methi bunch, carrot ooty 500g, beetroot...
# 6  [carrot ooty 500g, palak bunch, dhaniya bunch, mint bunch, garlic 200g, ginger 250 gm, pumpkin 500gm pc, beetroot 500g, green chilli 100 gm, lemon 200g, methi bunch, curry leaves, french beans 500...
# 2  [methi bunch, garlic 200g, carrot ooty 500g, beetroot 500g, palak bunch, dhaniya bunch, curry leaves, ginger 250 gm, lemon 200g, parwal 250g, ladies finger 250g, green capsicum 500g, cauliflower, ...
# 7  [carrot ooty 500g, raw banana 500 gm, ginger 250 gm, pumpkin 500gm pc, lemon 200g, raw papaya 1pc 500g, french beans 500g, green capsicum 500g, tomatoes 1kg, tinda 500g, dudhi, potatoes 1kg, onion...
# 3  [ginger 250 gm, methi bunch, dhaniya bunch, garlic 200g, lemon 200g, palak bunch, pumpkin 500gm pc, green capsicum 500g, cabbage, ladies finger 250g, tomatoes 1kg, kheera cucumber 500g, tinda 500g...
# 0                 [lemon 200g, palak bunch, carrot ooty 500g, dhaniya bunch, garlic 200g, ginger 250 gm, raw mango 500g, onions 1kg, potatoes 1kg, ladies finger 250g, tomatoes 1kg, kheera cucumber 500g]
# 4                                                                   [dhaniya bunch, palak bunch, carrot ooty 500g, kheera cucumber 500g, french beans 500g, broad beans 500g, cauliflower, brinjal bharta]

# %% [markdown]
# ### Exotic vegetables

# %%
exotic_vegies=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='SALADS, EXOTIC VEGETABLES']
exotic_vegies_grouped=exotic_vegies.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

exotic_vegies_unique_names=exotic_vegies.groupby('item name')['name'].unique().reset_index()

exotic_vegies_unique=exotic_vegies.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(exotic_vegies_unique,exotic_vegies_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,exotic_vegies_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df
# Out:
#                        item name  buyers count  sales amount  \
# 0                 avocados 2 pcs             2        1230.0
# 1                   baby spinach             3         330.0
# 2      babybella mushroom 2packs             2         525.0
# 3                 babycorn 1pack             3         195.0
# 4           blueberries 2punnets             3        3100.0
# 5                   broccoli 1pc             7        1260.0
# 6   button white mushroom 2packs             3         980.0
# 7                    celery 250g             3         210.0
# 8           cherry tomatoes 250g             5         935.0
# 9                       delivery            12         315.0
# 10            green zucchini 1pc             4         425.0
# 11          iceberg lettuce 1 pc             4         425.0
# 12                 italian basil             1          90.0
# 13        japanese cucumber 500g             2         680.0
# 14       red yellow capsicum 1pc             4         700.0
# 15                     s aragula             3         550.0
# 16                  s butterhead             2         220.0
# 17                   s curl kale             3         330.0
# 18                 s lettuce mix             3         330.0
# 19                     s romaine             2         220.0
# 20                   s spicy mix             2         220.0
# 21                 s summercrisp             2         220.0
# 22           yellow zucchini 1pc             4         300.0
#
#     item sales quantity  \
# 0                     2
# 1                     3
# 2                     3
# 3                     3
# 4                     6
# 5                    14
# 6                     7
# 7                     3
# 8                    11
# 9                    21
# 10                    5
# 11                    5
# 12                    1
# 13                    8
# 14                    5
# 15                    5
# 16                    2
# 17                    3
# 18                    3
# 19                    2
# 20                    2
# 21                    2
# 22                    4
#
#                                                                                                                                                                           buyers Name
# 0                                                                                                                                                  [indrani jafar, tanvi jain patyal]
# 1                                                                                                                                  [simeen oshidar, indrani jafar, tanvi jain patyal]
# 2                                                                                                                                                 [simeen oshidar, tanvi jain patyal]
# 3                                                                                                                                   [richa chourasia, parul kumar, tanvi jain patyal]
# 4                                                                                                                                        [simeen oshidar, ruchi  wahi, indrani jafar]
# 5                                                                                   [deepti moga, simeen oshidar, indrani jafar, ruchi  wahi, parul kumar, trupti, tanvi jain patyal]
# 6                                                                                                                                     [indrani jafar, ruchi  wahi, tanvi jain patyal]
# 7                                                                                                                                           [deepti moga, ruchi  wahi, indrani jafar]
# 8                                                                                                        [indrani jafar, deepti moga, simeen oshidar, ruchi  wahi, tanvi jain patyal]
# 9   [indrani jafar, smita dalal, deepti moga, harsha bangari, simeen oshidar, preeti rathod, ruchi  wahi, ashish billimoria, richa chourasia, parul kumar, trupti, tanvi jain patyal]
# 10                                                                                                                       [deepti moga, ruchi  wahi, indrani jafar, tanvi jain patyal]
# 11                                                                                                                       [simeen oshidar, richa chourasia, trupti, tanvi jain patyal]
# 12                                                                                                                                                                [tanvi jain patyal]
# 13                                                                                                                                                       [indrani jafar, deepti moga]
# 14                                                                                                                    [indrani jafar, simeen oshidar, ruchi  wahi, tanvi jain patyal]
# 15                                                                                                                                       [indrani jafar, deepti moga, simeen oshidar]
# 16                                                                                                                                                   [smita dalal, ashish billimoria]
# 17                                                                                                                                        [deepti moga, preeti rathod, indrani jafar]
# 18                                                                                                                               [harsha bangari, richa chourasia, tanvi jain patyal]
# 19                                                                                                                                                   [indrani jafar, richa chourasia]
# 20                                                                                                                                                     [smita dalal, richa chourasia]
# 21                                                                                                                                                        [ashish billimoria, trupti]
# 22                                                                                                                   [ruchi  wahi, richa chourasia, indrani jafar, tanvi jain patyal]

# %%
exotic_vegies_date=exotic_vegies.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_exotic_vegies=exotic_vegies.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(exotic_vegies_date,unique_exotic_vegies, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#         date  item payment amount(INR)   \
# 8 2023-06-05                     2955.0
# 6 2023-05-28                     2200.0
# 5 2023-05-22                     1925.0
# 1 2023-05-08                     1705.0
# 4 2023-05-15                     1565.0
# 3 2023-05-14                     1290.0
# 0 2023-05-07                     1010.0
# 7 2023-05-29                      880.0
# 2 2023-05-13                      260.0
#
#                                                                                                                                                                                                  item name
# 8  [japanese cucumber 500g, button white mushroom 2packs, s aragula, cherry tomatoes 250g, red yellow capsicum 1pc, delivery, s butterhead, s spicy mix, green zucchini 1pc, celery 250g, s curl kale, ...
# 6  [delivery, japanese cucumber 500g, yellow zucchini 1pc, celery 250g, green zucchini 1pc, baby spinach, broccoli 1pc, s lettuce mix, babycorn 1pack, cherry tomatoes 250g, italian basil, button whit...
# 5  [blueberries 2punnets, delivery, cherry tomatoes 250g, celery 250g, green zucchini 1pc, broccoli 1pc, button white mushroom 2packs, s summercrisp, iceberg lettuce 1 pc, baby spinach, s curl kale, ...
# 1                                           [delivery, s curl kale, button white mushroom 2packs, broccoli 1pc, cherry tomatoes 250g, avocados 2 pcs, japanese cucumber 500g, s summercrisp, s butterhead]
# 4              [s romaine, blueberries 2punnets, cherry tomatoes 250g, s aragula, delivery, babycorn 1pack, yellow zucchini 1pc, s lettuce mix, s spicy mix, iceberg lettuce 1 pc, japanese cucumber 500g]
# 3                                                [broccoli 1pc, iceberg lettuce 1 pc, delivery, red yellow capsicum 1pc, blueberries 2punnets, cherry tomatoes 250g, s aragula, babybella mushroom 2packs]
# 0                                                                                    [broccoli 1pc, delivery, green zucchini 1pc, blueberries 2punnets, yellow zucchini 1pc, button white mushroom 2packs]
# 7                                                                                                            [broccoli 1pc, cherry tomatoes 250g, red yellow capsicum 1pc, delivery, blueberries 2punnets]
# 2                                                                                                                                                                 [broccoli 1pc, delivery, babycorn 1pack]

# %%
combined_data_payment_completed['name'].unique()
# Out:
# array(['ritu sinha', 'tanvi jain patyal', 'shradha goenka', 'naina',
#        'indrani jafar', 'parul kumar', 'anubha', 'smita dalal',
#        'deepti moga', 'harsha bangari', 'simeen oshidar', 'sonavi desai',
#        'kanchan', 'ruchi  wahi', 'richa chourasia', 'noyna dutt',
#        'ekta bhatia', 'archana swami', 'preeti rathod',
#        'ashish billimoria', 'payal', 'yogesh thakkar', 'padmasree',
#        'shwetha kallaje', 'trupti', 'neetu vinayek', 'aneesha mehra',
#        'ushma', 'jasma kapadia', 'vijay dubey'], dtype=object)

# %% [markdown]
# #### Indrani's data

# %%
indrani_data=combined_data_payment_completed[combined_data_payment_completed['name']=='indrani jafar']
indrani_data_grouped=indrani_data.groupby('item name')['item quantity','item payment amount(INR) '].sum().reset_index()
indrani_data_grouped.sort_values(by='item payment amount(INR) ',ascending=False)
# Out:
#                        item name  item quantity  item payment amount(INR)
# 0                 avocados 2 pcs              3                     1830.0
# 38             salted pista 500g              1                     1450.0
# 30                pine nuts 100g              2                     1380.0
# 19                    jamun 500g              3                     1060.0
# 24                  makhana 250g              2                      670.0
# 21                      kiwi box              3                      600.0
# 20        japanese cucumber 500g              7                      590.0
# 5   button white mushroom 2packs              4                      560.0
# 2           blueberries 2punnets              1                      500.0
# 9           cherry tomatoes 250g              5                      425.0
# 13         elaichi banana 1dozen              3                      360.0
# 29                      pear 1kg              1                      300.0
# 35                     s aragula              2                      220.0
# 28             peach indian 500g              1                      200.0
# 26                    papaya 1pc              2                      200.0
# 4                   broccoli 1pc              2                      180.0
# 40                    watermelon              1                      155.0
# 10                      delivery             10                      150.0
# 23                    lemon 200g              2                      144.0
# 34       red yellow capsicum 1pc              1                      140.0
# 25                 muskmelon 1pc              1                      135.0
# 22            ladies finger 250g              4                      124.0
# 36                   s curl kale              1                      110.0
# 37                     s romaine              1                      110.0
# 1                   baby spinach              1                      110.0
# 15                 ginger 250 gm              2                      107.0
# 7                    cauliflower              2                      103.0
# 18            green zucchini 1pc              1                       85.0
# 39                  tomatoes 1kg              2                       80.0
# 27                   parwal 250g              2                       80.0
# 6               carrot ooty 500g              2                       79.0
# 31              pumpkin 500gm pc              2                       78.0
# 41           yellow zucchini 1pc              1                       75.0
# 12                         dudhi              2                       74.0
# 8                    celery 250g              1                       70.0
# 14             french beans 500g              1                       64.0
# 33           raw papaya 1pc 500g              1                       42.0
# 16           green capsicum 500g              1                       42.0
# 32             raw banana 500 gm              1                       40.0
# 3                 brinjal bharta              1                       40.0
# 11                 dhaniya bunch              1                       39.0
# 17           green chilli 100 gm              1                       24.0

# %%
indrani_orders = combined_data_payment_completed[(combined_data_payment_completed['name'] == 'indrani jafar')]



indrani_order_dates = indrani_orders.groupby('date')['item name'].unique().reset_index()
indrani_order_dates
# Out:
#         date  \
# 0 2023-05-08
# 1 2023-05-10
# 2 2023-05-13
# 3 2023-05-15
# 4 2023-05-22
# 5 2023-05-24
# 6 2023-05-28
# 7 2023-05-29
# 8 2023-06-04
# 9 2023-06-05
#
#                                                                                                                                                                                                  item name
# 0    [parwal 250g, ladies finger 250g, green capsicum 500g, cauliflower, tomatoes 1kg, button white mushroom 2packs, broccoli 1pc, cherry tomatoes 250g, delivery, avocados 2 pcs, japanese cucumber 500g]
# 1                                                                                                                                                        [makhana 250g, salted pista 500g, pine nuts 100g]
# 2                                                                                                                                        [kiwi box, delivery, elaichi banana 1dozen, watermelon, pear 1kg]
# 3  [pumpkin 500gm pc, carrot ooty 500g, green chilli 100 gm, dhaniya bunch, lemon 200g, ginger 250 gm, tomatoes 1kg, parwal 250g, french beans 500g, dudhi, s romaine, blueberries 2punnets, cherry tom...
# 4  [carrot ooty 500g, raw banana 500 gm, ginger 250 gm, pumpkin 500gm pc, lemon 200g, raw papaya 1pc 500g, cauliflower, ladies finger 250g, dudhi, brinjal bharta, cherry tomatoes 250g, baby spinach, ...
# 5                                                                                                             [avocados 2 pcs, papaya 1pc, jamun 500g, delivery, elaichi banana 1dozen, peach indian 500g]
# 6                                                                                                                 [delivery, japanese cucumber 500g, yellow zucchini 1pc, celery 250g, green zucchini 1pc]
# 7                                                                                                                                                          [muskmelon 1pc, kiwi box, jamun 500g, delivery]
# 8                                                                                                                                [avocados 2 pcs, delivery, jamun 500g, papaya 1pc, elaichi banana 1dozen]
# 9                                                                               [japanese cucumber 500g, button white mushroom 2packs, s aragula, cherry tomatoes 250g, red yellow capsicum 1pc, delivery]

# %% [markdown]
# # END

# %%
import pandas as pd
import glob
import os
import warnings
import matplotlib.pyplot as plt
import matplotlib
from pandas.io.json import json_normalize
warnings.filterwarnings("ignore")
pd.set_option('display.max_colwidth', 200)

# %%
print(os.getcwd())
# Out:
# C:\Users\Manshi\Desktop\combine Razorpay

# %%
directory = r'C:\Users\Manshi\Desktop\combine Razorpay\\'
csv_files = [file for file in os.listdir(directory) if file.endswith('p.csv')]
csv_files
# Out:
# ['April 23 p.csv',
#  'Aug 22 p.csv',
#  'dec 22 p.csv',
#  'feb 23 p.csv',
#  'Jan 23 p.csv',
#  'july 22 p.csv',
#  'june 23 p.csv',
#  'march 23 p.csv',
#  'may 23 p.csv',
#  'Nov 22 p.csv',
#  'oct 22 p.csv',
#  'sept 22 p.csv']

# %%
combined_data = pd.DataFrame()
for files in csv_files:
    data=pd.read_csv(files)
    combined_data = pd.concat([combined_data,data],ignore_index=True)

# %%
directory = r'C:\Users\Manshi\Desktop\combine Razorpay\\'
csv_files = [file for file in os.listdir(directory) if file.endswith('orders.csv')]
csv_files
# Out:
# ['april 2023 orders.csv',
#  'aug 22 orders.csv',
#  'dec 2022 orders.csv',
#  'feb 2023 orders.csv',
#  'jan 23 orders.csv',
#  'july 22 orders.csv',
#  'march 2023 orders.csv',
#  'May 2023 orders.csv',
#  'Nov 2022 orders.csv',
#  'oct 2022 orders.csv',
#  'sept 2022 orders.csv']

# %%
orders = pd.DataFrame()
for files in csv_files:
    data=pd.read_csv(files)
    orders = pd.concat([orders,data],ignore_index=True)

# %%
# df=pd.read_csv('may 2023.csv')
# orders=pd.read_csv('May orders 2023.csv')

# %%
orders.rename(columns={'id':'order_id'},inplace=True)

# %%
combined_data
# Out:
#         payment page id                payment page title  \
# 0     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 1     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 2     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 3     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 4     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# ...                 ...                               ...
# 6338  pl_KLb4g8XBKzDjn6      FRUIT BASKET DAILY SEPTEMBER
# 6339  pl_KLb4g8XBKzDjn6      FRUIT BASKET DAILY SEPTEMBER
# 6340  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
# 6341  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
# 6342  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
#
#              payment date              order_id                    item name  \
# 0     09/04/2023 23:39:04  order_Lbmout4V0g7BjF                   Watermelon
# 1     09/04/2023 23:39:04  order_Lbmout4V0g7BjF                MUSKMELON 1PC
# 2     09/04/2023 23:39:04  order_Lbmout4V0g7BjF              DESI PAPAYA 1PC
# 3     09/04/2023 23:39:04  order_Lbmout4V0g7BjF        ELAICHI BANANA 1DOZEN
# 4     09/04/2023 20:15:54  order_LbjMO6E1YlnOoF               AVOCADOS 2 PCS
# ...                   ...                   ...                          ...
# 6338  29/09/2022 09:34:44  order_KNZruF53reFCtW                     Delivery
# 6339  29/09/2022 09:34:44  order_KNZruF53reFCtW            IMPORTED KIWI BOX
# 6340  27/09/2022 14:58:38  order_KMsJWoihU7QYy6     PREMIUM JUMBO DATES 500G
# 6341  29/09/2022 09:38:03  order_KNZvIoQVGzGL9o  MIX NUTS ROASTED AND SALTED
# 6342  29/09/2022 09:38:03  order_KNZvIoQVGzGL9o             BRAZIL NUTS 200G
#
#       item amount  item quantity  item payment amount  total payment amount  \
# 0           155.0            1.0                155.0                 608.0
# 1           135.0            1.0                135.0                 608.0
# 2           100.0            2.0                200.0                 608.0
# 3           118.0            1.0                118.0                 608.0
# 4           685.0            1.0                685.0                1935.0
# ...           ...            ...                  ...                   ...
# 6338         15.0            1.0                 15.0                1685.0
# 6339        185.0            1.0                185.0                1685.0
# 6340        815.0            1.0                815.0                 815.0
# 6341        950.0            1.0                950.0                1510.0
# 6342        560.0            1.0                560.0                1510.0
#
#      currency payment status          payment id
# 0         INR       captured  pay_Lbmp6HExTAkM5g
# 1         INR       captured  pay_Lbmp6HExTAkM5g
# 2         INR       captured  pay_Lbmp6HExTAkM5g
# 3         INR       captured  pay_Lbmp6HExTAkM5g
# 4         INR         failed  pay_LbjMWLqLhpMohI
# ...       ...            ...                 ...
# 6338      INR       captured  pay_KNZs4UlODcdwbm
# 6339      INR       captured  pay_KNZs4UlODcdwbm
# 6340      INR       captured  pay_KMsK0vVFivSewT
# 6341      INR       captured  pay_KNZvbmKjqIktA4
# 6342      INR       captured  pay_KNZvbmKjqIktA4
#
# [6343 rows x 12 columns]

# %%
orders['name']=orders['notes'].str.split(',').str[0].str.split('"').str[3]
orders['email']=orders['notes'].str.split(',').str[1].str.split('"').str[3]

# %%
orders.drop(columns=['amount','amount_paid','amount_due','currency','receipt','offer_id','status','attempts','notes','created_at'],inplace=True)

# %%
orders
# Out:
#                   order_id              name                     email
# 0     order_LYNixREtZ5yK9S          Kanchan    Samtani.kanchan@bcg.com
# 1     order_LYX61KR1NfQCKT      Sonavi Desai         sonavid@gmail.com
# 2     order_LYX7VqyBqc61HI      Sonavi Desai         sonavid@gmail.com
# 3     order_LYXuMMuY5pVnm9      Sonavi Desai         sonavid@gmail.com
# 4     order_LYnHqGt69fvok7       Meher Mirza   mehermirza123@gmail.com
# ...                    ...               ...                       ...
# 1206  order_KNZrbTnOlpRCNl     Jasma Kapadia       jasmak999@yahoo.com
# 1207  order_KNZruF53reFCtW     Jasma Kapadia       jasmak999@yahoo.com
# 1208  order_KNZvIoQVGzGL9o   Amirbanu Virji          ajvirji@gmail.com
# 1209  order_KNy2q87jB125jD               NaN                       NaN
# 1210  order_KO7GgmwXOXiFRF  Gitanjali Anand   sangeeta@akinariwala.com
#
# [1211 rows x 3 columns]

# %%
orders.isnull().sum()
# Out:
# order_id     0
# name        51
# email       51
# dtype: int64

# %%
combined_data[combined_data['order_id'].isnull()].groupby('item payment amount').sum().reset_index()
# Out:
#    item payment amount  item amount  item quantity  total payment amount
# 0                  0.0          0.0            0.0                   0.0

# %%
combined_data=pd.merge(combined_data,orders,on='order_id',how="left")

# %%
combined_data[combined_data['name'].isnull()]['order_id']
# Out:
# 1489                     NaN
# 2237                     NaN
# 2822                     NaN
# 3249    order_LyW1wBiKD3zNrX
# 3250    order_LyW1wBiKD3zNrX
#                 ...
# 5087    order_Lwys2qrNfCncTf
# 5099    order_LxjQZeDPofpyQH
# 5100    order_LxjQZeDPofpyQH
# 5101    order_LxjQZeDPofpyQH
# 5102    order_LxjQZeDPofpyQH
# Name: order_id, Length: 267, dtype: object

# %%
combined_data[combined_data['name'].isnull()]['item payment amount'].sum()
# Out:
# 55959.0

# %%
combined_data.isnull().sum()
# Out:
# payment page id           0
# payment page title        0
# payment date              6
# order_id                  6
# item name                 6
# item amount               6
# item quantity             6
# item payment amount       0
# total payment amount      6
# currency                  6
# payment status            6
# payment id                6
# name                    267
# email                   267
# dtype: int64

# %%
combined_data.dropna(subset=['order_id'],inplace=True)

# %%
combined_data[combined_data['name'].isnull()]
# Out:
#         payment page id      payment page title         payment date  \
# 3249  pl_LxonlA4k4hCi7b  FRUIT BASKET - JUNE 10  06/06/2023 10:10:37
# 3250  pl_LxonlA4k4hCi7b  FRUIT BASKET - JUNE 10  06/06/2023 10:10:37
# 3251  pl_LxonlA4k4hCi7b  FRUIT BASKET - JUNE 10  06/06/2023 10:10:37
# 3252  pl_LxonlA4k4hCi7b  FRUIT BASKET - JUNE 10  06/06/2023 10:10:37
# 3253  pl_LxonlA4k4hCi7b  FRUIT BASKET - JUNE 10  06/06/2023 10:10:37
# ...                 ...                     ...                  ...
# 5087  pl_Lw77t4FZvxried    FRUIT BASKET - JUNE3  02/06/2023 13:05:14
# 5099  pl_Lw77t4FZvxried    FRUIT BASKET - JUNE3  04/06/2023 10:37:54
# 5100  pl_Lw77t4FZvxried    FRUIT BASKET - JUNE3  04/06/2023 10:37:54
# 5101  pl_Lw77t4FZvxried    FRUIT BASKET - JUNE3  04/06/2023 10:37:54
# 5102  pl_Lw77t4FZvxried    FRUIT BASKET - JUNE3  04/06/2023 10:37:54
#
#                   order_id           item name  item amount  item quantity  \
# 3249  order_LyW1wBiKD3zNrX          JAMUN 500G        400.0            1.0
# 3250  order_LyW1wBiKD3zNrX      AVOCADOS 2 PCS        600.0            1.0
# 3251  order_LyW1wBiKD3zNrX          PAPAYA 1PC        100.0            1.0
# 3252  order_LyW1wBiKD3zNrX       MUSKMELON 1PC        135.0            1.0
# 3253  order_LyW1wBiKD3zNrX            DELIVERY         15.0            1.0
# ...                    ...                 ...          ...            ...
# 5087  order_Lwys2qrNfCncTf  HAPUS MANGOES 1DOZ        950.0            1.0
# 5099  order_LxjQZeDPofpyQH   MOSUMBI LOCAL 1kg        165.0            1.0
# 5100  order_LxjQZeDPofpyQH            KIWI BOX        200.0            1.0
# 5101  order_LxjQZeDPofpyQH   BLUEBERRIES 2 BOX        550.0            1.0
# 5102  order_LxjQZeDPofpyQH            DELIVERY         15.0            1.0
#
#       item payment amount  total payment amount currency payment status  \
# 3249                400.0                1250.0      INR       captured
# 3250                600.0                1250.0      INR       captured
# 3251                100.0                1250.0      INR       captured
# 3252                135.0                1250.0      INR       captured
# 3253                 15.0                1250.0      INR       captured
# ...                   ...                   ...      ...            ...
# 5087                950.0                2295.0      INR       captured
# 5099                165.0                 930.0      INR       captured
# 5100                200.0                 930.0      INR       captured
# 5101                550.0                 930.0      INR       captured
# 5102                 15.0                 930.0      INR       captured
#
#               payment id name email
# 3249  pay_LyW280F25GQytS  NaN   NaN
# 3250  pay_LyW280F25GQytS  NaN   NaN
# 3251  pay_LyW280F25GQytS  NaN   NaN
# 3252  pay_LyW280F25GQytS  NaN   NaN
# 3253  pay_LyW280F25GQytS  NaN   NaN
# ...                  ...  ...   ...
# 5087  pay_Lwys6fwwkJg9Ij  NaN   NaN
# 5099  pay_LxjQigbGWf4sMa  NaN   NaN
# 5100  pay_LxjQigbGWf4sMa  NaN   NaN
# 5101  pay_LxjQigbGWf4sMa  NaN   NaN
# 5102  pay_LxjQigbGWf4sMa  NaN   NaN
#
# [261 rows x 14 columns]

# %%
combined_data.rename(columns={'item payment amount':'item payment amount(INR) '},inplace=True)

# %%
combined_data_copy=combined_data.copy()

# %% [markdown]
# ### checking unique values and their count in each columns

# %%
combined_data_copy['payment page id'].nunique()
# Out:
# 187

# %%
combined_data_copy['payment page id'].value_counts()
# Out:
# pl_JwhO3HTiMTVyHX    123
# pl_LjSEzj8c6pW6eg     92
# pl_LgPq1hiWfh7uZE     88
# pl_KGSvSXU36ZVMir     86
# pl_K5QoMWpw63vMtn     86
#                     ...
# pl_KteK7pELT57gIt      2
# pl_KqX6FyOFgY4VZb      2
# pl_M1Nv8PzDD98HbR      1
# pl_LB4JApucSL4NEl      1
# pl_KSVvJdQdjUzF8N      1
# Name: payment page id, Length: 187, dtype: int64

# %%
combined_data_copy['payment page title'].nunique()
# Out:
# 164

# %%
combined_data_copy['payment page title'].value_counts()
# Out:
# FRUIT BASKET AUGUST                        232
# FRUIT BASKET JULY                          152
# FRUIT BASKET OCTOBER                       139
# FRUIT BASKET DAILY                         115
# FRUIT BASKET DAILY SEPTEMBER               108
#                                           ...
# HERBS & SALADS MARCH 25                      2
# SALADS, EXOTIC VEGETABLES DEC 20             2
# MALAWI MANGO MANIA                           2
# DRYFRUITS, SEEDS, NUTS FEBRUARY 08           1
# DRYFRUITS, SEEDS, NUTS. JUNE 14th-18 th      1
# Name: payment page title, Length: 164, dtype: int64

# %%
combined_data_copy['order_id'].nunique()
# Out:
# 1088

# %%
combined_data_copy['payment id'].nunique()
# Out:
# 1177

# %%
df=combined_data_copy.groupby('order_id')['payment id'].first().reset_index()
combined_data_copy=pd.merge(combined_data_copy,df,on='order_id',how="left")

# %%
combined_data_copy['payment id']=combined_data_copy['payment id_y']
combined_data_copy.drop(columns=['payment id_x','payment id_y'],inplace=True)

# %%
combined_data_copy
# Out:
#         payment page id                payment page title  \
# 0     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 1     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 2     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 3     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# 4     pl_La3sRsT9Tonx59             FRUIT BASKET APRIL 10
# ...                 ...                               ...
# 6332  pl_KLb4g8XBKzDjn6      FRUIT BASKET DAILY SEPTEMBER
# 6333  pl_KLb4g8XBKzDjn6      FRUIT BASKET DAILY SEPTEMBER
# 6334  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
# 6335  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
# 6336  pl_KLb5bJA1tqXWul  DRYFRUITS, SEEDS, NUTS SEPTEMBER
#
#              payment date              order_id                    item name  \
# 0     09/04/2023 23:39:04  order_Lbmout4V0g7BjF                   Watermelon
# 1     09/04/2023 23:39:04  order_Lbmout4V0g7BjF                MUSKMELON 1PC
# 2     09/04/2023 23:39:04  order_Lbmout4V0g7BjF              DESI PAPAYA 1PC
# 3     09/04/2023 23:39:04  order_Lbmout4V0g7BjF        ELAICHI BANANA 1DOZEN
# 4     09/04/2023 20:15:54  order_LbjMO6E1YlnOoF               AVOCADOS 2 PCS
# ...                   ...                   ...                          ...
# 6332  29/09/2022 09:34:44  order_KNZruF53reFCtW                     Delivery
# 6333  29/09/2022 09:34:44  order_KNZruF53reFCtW            IMPORTED KIWI BOX
# 6334  27/09/2022 14:58:38  order_KMsJWoihU7QYy6     PREMIUM JUMBO DATES 500G
# 6335  29/09/2022 09:38:03  order_KNZvIoQVGzGL9o  MIX NUTS ROASTED AND SALTED
# 6336  29/09/2022 09:38:03  order_KNZvIoQVGzGL9o             BRAZIL NUTS 200G
#
#       item amount  item quantity  item payment amount(INR)   \
# 0           155.0            1.0                      155.0
# 1           135.0            1.0                      135.0
# 2           100.0            2.0                      200.0
# 3           118.0            1.0                      118.0
# 4           685.0            1.0                      685.0
# ...           ...            ...                        ...
# 6332         15.0            1.0                       15.0
# 6333        185.0            1.0                      185.0
# 6334        815.0            1.0                      815.0
# 6335        950.0            1.0                      950.0
# 6336        560.0            1.0                      560.0
#
#       total payment amount currency payment status             name  \
# 0                    608.0      INR       captured      Parul kumar
# 1                    608.0      INR       captured      Parul kumar
# 2                    608.0      INR       captured      Parul kumar
# 3                    608.0      INR       captured      Parul kumar
# 4                   1935.0      INR         failed      Nisha singh
# ...                    ...      ...            ...              ...
# 6332                1685.0      INR       captured    Jasma Kapadia
# 6333                1685.0      INR       captured    Jasma Kapadia
# 6334                 815.0      INR       captured  Leena Sivakumar
# 6335                1510.0      INR       captured  Amirbanu Virji
# 6336                1510.0      INR       captured  Amirbanu Virji
#
#                           email          payment id
# 0      2014parulkumar@gmail.com  pay_Lbmp6HExTAkM5g
# 1      2014parulkumar@gmail.com  pay_Lbmp6HExTAkM5g
# 2      2014parulkumar@gmail.com  pay_Lbmp6HExTAkM5g
# 3      2014parulkumar@gmail.com  pay_Lbmp6HExTAkM5g
# 4             anish24@gmail.com  pay_LbjMWLqLhpMohI
# ...                         ...                 ...
# 6332        jasmak999@yahoo.com  pay_KNZs4UlODcdwbm
# 6333        jasmak999@yahoo.com  pay_KNZs4UlODcdwbm
# 6334  leena.sivakumar@gmail.com  pay_KMsK0vVFivSewT
# 6335          ajvirji@gmail.com  pay_KNZvbmKjqIktA4
# 6336          ajvirji@gmail.com  pay_KNZvbmKjqIktA4
#
# [6337 rows x 14 columns]

# %%
# values_to_drop = ['pay_LUqE7lVkgOU9bH','pay_LUvsd49Yc5Itaz','pay_LXE2GgLFFZUL3l','pay_LZJWgSvAQc1gCS','pay_LZxtNQumNMNGY3','pay_LZxtUuQsPr4hEh']

# # Drop rows where Gender column has values in the list
# combined_data_copy = combined_data_copy[~combined_data_copy['payment id'].isin(values_to_drop)]

# %%
df=combined_data_copy.groupby('order_id')['payment id'].nunique().reset_index()
df[df['payment id']>1]
# Out:
# Empty DataFrame
# Columns: [order_id, payment id]
# Index: []

# %%
combined_data_copy['item name'].unique()
# Out:
# array(['Watermelon', 'MUSKMELON 1PC', 'DESI PAPAYA 1PC',
#        'ELAICHI BANANA 1DOZEN', 'AVOCADOS 2 PCS', 'HAPUS MANGOES 1DOZ',
#        'FLAME RED GRAPES 1 KG', 'KIWI BOX', 'FIJI APPLES 1KG',
#        'POMEGRANATE 1KG', 'PAIREE MANGOES 1 DOZ', 'CHICKOO 1KG',
#        'REGULAR BANANA 1 DOZ', 'BLUEBERRIES 2 BOX', 'PEAR 1KG',
#        'MOSUMBI LOCAL 1kg', 'MANDARIN MINI ORANGES 1KG',
#        'RED YELLOW CAPSICUM 1PC', 'S LETTUCE MIX', 'PURPLE CABBAGE 1 PC',
#        'DELIVERY', 'S ROMAINE', 'S SUMMERCRISP', 'ICEBERG LETTUCE 1 PC',
#        'S BUTTERHEAD', 'JAPANESE CUCUMBER 500G', 'S ARAGULA',
#        'BABY SPINACH', 'BUTTON WHITE MUSHROOM 2PACKS', 'BROCCOLI 1PC',
#        'GREEN ZUCCHINI 1PC', 'YELLOW ZUCCHINI 1PC', 'Sweet Potato 500g',
#        'Green Capsicum 500g', 'Ladies Finger 250g', 'Potatoes 1kg',
#        'Cucumber White 500g', 'Dudhi', 'Cauliflower', 'French Beans 500g',
#        'Drumsticks 250g', 'Cabbage', 'Tomatoes 1kg', 'Onions 1kg',
#        'Brinjal Stripes Kateri 500g', 'Tendli 500g', 'Gavar 500g',
#        'Brinjal Bharta', 'Bitter Gourd 500g', 'Kheera Cucumber 500g',
#        'Ridge Gourd 500g', 'Pumpkin 500gm pc', 'Dhaniya Bunch',
#        'Palak Bunch', 'Mint Bunch', 'Sponge Gourd 300g',
#        'Carrot Ooty 500g', 'Lemon 200g', 'Fresh Turmeric 250g',
#        'Ginger 250 gm', 'Sambar Onions 500g', 'Curry Leaves',
#        'Methi Bunch', 'Garlic 200g', 'Beetroot 500g',
#        'Green Chilli 100 gm', 'RAIPUR GUAVA 1KG', 'SOFT DATES 500G',
#        'GOURMET BLACK RASINS 500G', 'WALNUTS 500G', 'GOLDEN RASINS 500G',
#        'DRIED CRANBERRIES 500G', 'PREMIUM ALMONDS 500G',
#        'TURKISH APRICOT 200G', 'S SWISS CHARD', 'CHERRY TOMATOES 250G',
#        'IMPORTED BLUEBERRIES 2PUNNETS', 'BABYCORN 1PACK',
#        'Raw Mango 500g', 'Tinda 500g', 'Sweet Corn 2 Pc',
#        'Raw Papaya 1pc 500g', 'Chilli Bhaji 250g',
#        'Dill Leaves Sepu Bunch', 'Delivery', 'Amaranth Green',
#        'Mandarin Sweet Oranges 1kg', 'Amaranth Red Bunch', 'PRUNES 250G',
#        'MIXED SEEDS 250G', 'PUMPKIN SEEDS 250G', 'A2 GIR COW GHEE 500ML',
#        'JUMBO ANJEER 500G', 'PLAIN PISTA 500G', 'CASHEWS 500G',
#        'SALTED PISTA 500G', 'ROASTED SALTED MIXED NUTS 500G',
#        'MAKHANA 250G', 'MAMRA BADAM 500G', 'S SPICY MIX', 'Parwal 250g',
#        'Raw Banana 500 gm', 'Yam 500g', 'IMPORTED APPLES 1KG',
#        'PREMIUM JUMBO DATES 500G', 'Broad Beans 500g', 'CELERY 250G',
#        'S CURL KALE', 'BLUEBERRIES 2PUNNETS', 'HASS AVOCADOS 2 pcs',
#        'MIX NUTS ROASTED AND SALTED', 'BRAZIL NUTS 200G',
#        'WATERMELON 1PC', 'PREMIUM USA CHERRIES 500g',
#        'WASHINGTON APPLES 1KG', 'POMEGRANATE 1kg', 'SITAFAL 1kg',
#        'MANDARIN SMALL ORANGES 1kG', 'INDIAN PEAR 1kg',
#        'DESI FRUIT PACK PAPAYA MUSKMELON BANANA WATERMELON',
#        'LANDGA MANGOES 3KG', 'PLUM 500G', 'HASS AVOCADOS 2 PCS',
#        'FLAT DONUT PEACH 500G', 'IMPORTED KIWI BOX',
#        'NEW ZEALAND RED APPLES 1KG', 'ITALIAN BASIL',
#        'MANDARIN SWEET ORANGES 1KG', 'BABYBELLA MUSHROOM 2PACKS',
#        'BEAUTY PEAR 1kg', 'SWEETLIME IMPORTED 1kg', 'GREEN APPLE 1kg',
#        'INDIAN APPLES 1kg', 'PINEAPPLE', 'PECAN NUTS 200G',
#        'KESAR SAFFRON 1GRAM', 'PINE NUTS 100G', 'PEAR 1kg',
#        'AVANZA AVOCADOS 2 PCS', 'STRAWBERRIES 1 BOX', 'SITAFAL 1KG',
#        'NAGPUR ORANGES 1KG', 'AVOCADOS 2 pcs', 'INDIAN APPLES 1KG',
#        'HONEY AWLA 500G', 'RED GRAPES 500G',
#        'NEW ZEALAND QUEEN APPLES 1KG', 'BEAUTY PEAR 1KG',
#        'MALAWI MANGOES 15 PC BOX', 'MALTA ORANGES 1KG', 'CASHEWS 1KG',
#        'HAZELNUT 200G', 'MACADAMIA NUTS 200G',
#        'MANDARIN SMALL ORANGES 2KGS', 'IMPORTED RED APPLES 1KG',
#        'INDIAN RAMBUTAN 500G', 'HAPUS MANGOES 1 DOZEN',
#        'PREMIUM CHERRIES 1KG', 'RED GRAPES WITH SEEDS 500G',
#        'HIMACHAL APPLES 1KG', 'BEAUTY PEAR 500g', 'FLAT PEACH 500G',
#        'PREMIUM CHERRIES 500g', 'FLAME RED GRAPES SEEDLESS 500G',
#        'GREEN GRAPES SEEDLESS 500G', 'JAMUN 500G', 'PAPAYA 1PC',
#        'KESAR MANGOES 5KG BOX', 'KOLKATTA LYCHEES 1KG',
#        'TURKEY CHERRY 500G', 'Snake Gourd 500g', 'AVOCADOS 2 Pcs',
#        'BLUEBERRIES IMPORTED 2PUNNETS', 'IMPORTED CHERRIES 500G',
#        'LYCHEES 1KG', 'DEVGHAD HAPUS 1DOZ', 'RED CHERRY TOMATOES 250G',
#        'TURKISH CUCUMBER 500G', 'SNACKING PEPPER 200G', 'PARSLEY 50G',
#        'ARUGULA 100G', 'YELLOW CHERRY TOMATOES 250G', 'BABY SPINACH 100G',
#        'Small Brinjal 250g', 'Green Peas 500g', 'Beans Broad 500g',
#        'Ginger 250g', 'Palak 200g', 'Dill Leaves Sepu 200g', 'Mint 100g',
#        'Methi 200g', 'RED AMARANTHUS 200G',
#        'RED CHERRY TOMATOES PREMIUM 250G',
#        'MIXED NUTS ROASTED SALTED 500G', 'Curry Leaves 100g',
#        'Green Chilli 200g', 'Amaranth Red 400g', 'Red Carrot 500g',
#        'Amaranth Green 400g', 'Brinjal Nagpur 500g',
#        'English Cucumber 500g', 'SUMMERCRISP 100G',
#        'Amaranth Green Bunch', 'Bathua Saag Bunch', 'GUAVA 1KG',
#        'GIR KESAR MANGOES 5kg', 'PAYRI MANGOES 1DOZ', 'PEACH INDIAN 500G',
#        'PEACH INDIAN 1KG', 'MANDARIN SMALL ORANGES 1KG',
#        'ELAICHI BANANA PAPAYA MUSKMELON',
#        'RED YELLOW CAPSICUM RED CABBAGE COMBO', 'NAKA PEAR 1KG',
#        'PINK GRAPEFRUIT 1KG', 'AVANZA AVOCADOS 2 pcs',
#        'PING GRAPEFRUIT 1KG', 'DONUT PEACH 500G', 'NECTARINE 2 PCS'],
#       dtype=object)

# %%
combined_data_copy['item name'].nunique()
# Out:
# 218

# %%
combined_data_copy['name'].nunique()
# Out:
# 238

# %%
combined_data_copy['payment status'].nunique()
# Out:
# 2

# %%
combined_data_copy['payment status'].value_counts()
# Out:
# captured    4332
# failed      2005
# Name: payment status, dtype: int64

# %%
combined_data_copy.fillna('unknown',inplace=True)

# %%
combined_data_copy['name'].nunique()
# Out:
# 239

# %%
combined_data_copy['email'].nunique()
# Out:
# 126

# %%
combined_data_copy['name'].value_counts()
# Out:
# Indrani Jafar        444
# Michelle Baptist     379
# unknown              261
# kanchan              244
# Ruchi  Wahi          202
#                     ...
# Puja                   1
# Rachna Chattaram       1
# Preeti Maria           1
# Minu Agarwql           1
# Viji Ram               1
# Name: name, Length: 239, dtype: int64

# %%
combined_data_copy['currency'].value_counts()
# Out:
# INR    6337
# Name: currency, dtype: int64

# %% [markdown]
# #### cheching null value count

# %%
combined_data_copy.isnull().sum()
# Out:
# payment page id              0
# payment page title           0
# payment date                 0
# order_id                     0
# item name                    0
# item amount                  0
# item quantity                0
# item payment amount(INR)     0
# total payment amount         0
# currency                     0
# payment status               0
# name                         0
# email                        0
# payment id                   0
# dtype: int64

# %% [markdown]
# #### Droping apartment-no ,apartment and currency column

# %%
combined_data_copy.drop(columns=['currency'],inplace=True)

# %%
(combined_data_copy['payment status'].value_counts()/len(combined_data_copy))*100
# Out:
# captured    68.360423
# failed      31.639577
# Name: payment status, dtype: float64

# %%
combined_data_payment_completed=combined_data_copy

# %% [markdown]
# we can drop payment page id column and seggregte titles of item

# %%
combined_data_payment_completed.drop(columns=['payment page id'],inplace=True)

# %%
#removing payment id as we can get the desired information from orderid
combined_data_payment_completed.drop(columns=['payment id'],inplace=True)

# %%
combined_data_payment_completed[combined_data_payment_completed['name']=='unknown']['order_id'].nunique()
# Out:
# 46

# %%
#removing status as we only have successful payments now
combined_data_payment_completed.drop(columns=['payment status'],inplace=True)

# %%
dryfruits=combined_data_payment_completed['payment page title'].str.startswith('DRYFRUITS, SEEDS, NUTS')
combined_data_payment_completed.loc[dryfruits,'payment page title']='DRYFRUITS, SEEDS, NUTS'

fruits=combined_data_payment_completed['payment page title'].str.startswith('FRUIT BASKET')
combined_data_payment_completed.loc[fruits,'payment page title']='FRUIT BASKET'

exotic_vegies=combined_data_payment_completed['payment page title'].str.startswith('SALADS, EXOTIC VEGETABLES')
combined_data_payment_completed.loc[exotic_vegies,'payment page title']='SALADS, EXOTIC VEGETABLES'

vegies=combined_data_payment_completed['payment page title'].str.startswith('FORM')
combined_data_payment_completed.loc[vegies,'payment page title']='VEGETABLES'

herbs=combined_data_payment_completed['payment page title'].str.startswith('HERBS & SALADS')
combined_data_payment_completed.loc[herbs,'payment page title']='HERBS & SALADS'

herbs=combined_data_payment_completed['payment page title'].str.startswith('DAILY FRUIT')
combined_data_payment_completed.loc[herbs,'payment page title']='FRUIT BASKET'

# %%
#seggregating payment page title
combined_data_payment_completed['payment page title'].value_counts()
# Out:
# FRUIT BASKET                 179
# SALADS, EXOTIC VEGETABLES    140
# DRYFRUITS, SEEDS, NUTS        22
# Name: payment page title, dtype: int64

# %%
combined_data_payment_completed.columns
# Out:
# Index(['payment page title', 'payment date', 'order_id', 'item name',
#        'item amount', 'item quantity', 'item payment amount(INR) ',
#        'total payment amount', 'name', 'email'],
#       dtype='object')

# %%
combined_data_payment_completed['payment date']=combined_data_payment_completed['payment date'].astype(str)

# %%
combined_data_payment_completed['date']=combined_data_payment_completed['payment date'].str.split().str[0]

# %%
combined_data_payment_completed['time']=combined_data_payment_completed['payment date'].str.split().str[1]

# %%
combined_data_payment_completed['year']=combined_data_payment_completed['date'].str.split('/').str[2].astype(int)
combined_data_payment_completed['day']=combined_data_payment_completed['date'].str.split('/').str[0].astype(int)
combined_data_payment_completed['month']=combined_data_payment_completed['date'].str.split('/').str[1].astype(int)

# %%
combined_data_payment_completed['date'] = pd.to_datetime(combined_data_payment_completed[['year', 'month', 'day']])

# %%
combined_data_payment_completed['name'] = combined_data_payment_completed['name'].str.strip().str.lower()

# %%
combined_data_payment_completed['item name'] = combined_data_payment_completed['item name'].str.strip().str.lower()
combined_data_payment_completed['email'] = combined_data_payment_completed['email'].str.strip().str.lower()

# %%
print("number of days for which we are performing our analysis")
combined_data_payment_completed['date'].min()
# Out:
# number of days for which we are performing our analysis
# Timestamp('2022-07-01 00:00:00')

# %%
combined_data_payment_completed=combined_data_payment_completed[combined_data_payment_completed['month']==10]

# %%
df = combined_data_payment_completed
df_grouped = df.groupby('name')['email'].first().reset_index()
df_grouped = df_grouped.sort_values(by="name", ascending=True)




display(df_grouped)
# Out:
#                  name                      email
# 0          abha mehta      abhamehta26@gmail.com
# 1   ashish billimoria    billimoriaash@gmail.com
# 2         bharti shah          anish24@gmail.com
# 3     dilnaaz zaiwala         zaiwalad@gmail.com
# 4            dinmeher          anish24@gmail.com
# 5     gitanjali anand          gma6567@gmail.com
# 6       indrani jafar        ani.doley@gmail.com
# 7       jasma kapadia        jasmak999@yahoo.com
# 8         jaya prasad          anish24@gmail.com
# 9             kanchan    samtani.kanchan@bcg.com
# 10        kerbi patel     kerbipatel66@gmail.com
# 11    leena sivakumar  leena.sivakumar@gmail.com
# 12        meher mirza    mehermirza123@gmail.com
# 13         michelle b          anish24@gmail.com
# 14   michelle baptist      michbaptist@gmail.com
# 15     mrs.ruchi wahi      wahiruchi80@gmail.com
# 16              naina     naina.sharma@gmail.com
# 17              neetu    neetu.vinayek@gmail.com
# 18       nina dumasia   nina_dumasia@yahoo.co.in
# 19          padmasree      padmasree.r@gmail.com
# 20        parul kumar   2014parulkumar@gmail.com
# 21           preeti m          anish24@gmail.com
# 22    priyanka taneja   4priyankataneja@gmail.om
# 23       ritu kochhar        rchawla04@gmail.com
# 24      sanjay bandra          anish24@gmail.com
# 25    shwetha kallaje   shwethakallaje@gmail.com
# 26       sonavi desai          sonavid@gmail.com
# 27    sushama agarwal          anish24@gmail.com
# 28        toral patel      toral@accordindia.net
# 29             trupti         tmaskai5@gmail.com

# %%
row_index = combined_data_payment_completed[combined_data_payment_completed['name'] == 'michelle b'].index
combined_data_payment_completed.loc[row_index, 'name'] = 'michelle baptist'

# %%
# merged_df = pd.merge(combined_data_payment_completed,df_grouped, on='email', how='left')
# merged_df['name_x'].update(merged_df['name_y'])

# merged_df['name']=merged_df['name_x']

# combined_data_payment_completed=merged_df.drop(columns=['name_x','name_y'])

# %%
combined_data_payment_completed.groupby('name')['email'].unique().reset_index()
# Out:
#                  name                                                  email
# 0          abha mehta                                [abhamehta26@gmail.com]
# 1   ashish billimoria                              [billimoriaash@gmail.com]
# 2         bharti shah                                    [anish24@gmail.com]
# 3     dilnaaz zaiwala                                   [zaiwalad@gmail.com]
# 4            dinmeher                                    [anish24@gmail.com]
# 5     gitanjali anand                                    [gma6567@gmail.com]
# 6       indrani jafar                                  [ani.doley@gmail.com]
# 7       jasma kapadia                                  [jasmak999@yahoo.com]
# 8         jaya prasad                                    [anish24@gmail.com]
# 9             kanchan                              [samtani.kanchan@bcg.com]
# 10        kerbi patel                               [kerbipatel66@gmail.com]
# 11    leena sivakumar                            [leena.sivakumar@gmail.com]
# 12        meher mirza                              [mehermirza123@gmail.com]
# 13   michelle baptist             [anish24@gmail.com, michbaptist@gmail.com]
# 14     mrs.ruchi wahi                                [wahiruchi80@gmail.com]
# 15              naina                               [naina.sharma@gmail.com]
# 16              neetu                              [neetu.vinayek@gmail.com]
# 17       nina dumasia                             [nina_dumasia@yahoo.co.in]
# 18          padmasree                                [padmasree.r@gmail.com]
# 19        parul kumar                             [2014parulkumar@gmail.com]
# 20           preeti m                                    [anish24@gmail.com]
# 21    priyanka taneja  [4priyankataneja@gmail.om, 4priyankataneja@gmail.com]
# 22       ritu kochhar                                  [rchawla04@gmail.com]
# 23      sanjay bandra                                    [anish24@gmail.com]
# 24    shwetha kallaje                             [shwethakallaje@gmail.com]
# 25       sonavi desai                                    [sonavid@gmail.com]
# 26    sushama agarwal                                    [anish24@gmail.com]
# 27        toral patel                                [toral@accordindia.net]
# 28             trupti                                   [tmaskai5@gmail.com]

# %%
print("Total number of item bought by individuals")
combined_data_payment_completed['name'].value_counts().reset_index(name='number of item purchased(not unique)')
# Out:
# Total number of item bought by individuals
#                 index  number of item purchased(not unique)
# 0           padmasree                                    27
# 1               naina                                    22
# 2     gitanjali anand                                    22
# 3               neetu                                    21
# 4       jasma kapadia                                    20
# 5             kanchan                                    18
# 6      mrs.ruchi wahi                                    18
# 7       indrani jafar                                    18
# 8    michelle baptist                                    17
# 9        ritu kochhar                                    17
# 10        meher mirza                                    16
# 11        parul kumar                                    16
# 12       sonavi desai                                    15
# 13    dilnaaz zaiwala                                    13
# 14    priyanka taneja                                    13
# 15    shwetha kallaje                                    13
# 16  ashish billimoria                                     9
# 17        jaya prasad                                     8
# 18         abha mehta                                     6
# 19           dinmeher                                     5
# 20        kerbi patel                                     4
# 21             trupti                                     4
# 22        toral patel                                     4
# 23    sushama agarwal                                     3
# 24        bharti shah                                     3
# 25       nina dumasia                                     3
# 26           preeti m                                     2
# 27      sanjay bandra                                     2
# 28    leena sivakumar                                     2

# %%
categories=combined_data_payment_completed['payment page title'].unique()
categories_sales=dict()
for category in categories:
    categories_sales[category]=combined_data_payment_completed[combined_data_payment_completed['payment page title']==category]['item payment amount(INR) '].sum()

df = pd.DataFrame(categories_sales.items(), columns=["Category Name", "Amount"])
df_sorted = df.sort_values(by="Amount", ascending=False)
display(df_sorted)
# Out:
#                Category Name   Amount
# 0               FRUIT BASKET  41936.0
# 2     DRYFRUITS, SEEDS, NUTS  36500.0
# 1  SALADS, EXOTIC VEGETABLES  19380.0

# %%
items_amount=combined_data_payment_completed.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
items_amount.sort_values(by='item payment amount(INR) ', ascending=False)
# Out:
#                         item name  item payment amount(INR)   item quantity
# 49                   walnuts 500g                     9240.0            8.0
# 0                  avocados 2 pcs                     6600.0           11.0
# 31           premium almonds 500g                     6300.0            7.0
# 45              salted pista 500g                     5800.0            4.0
# 4               blueberries 2 box                     5535.0            9.0
# 22     mandarin small oranges 1kg                     5340.0           16.0
# 26     new zealand red apples 1kg                     4000.0           10.0
# 30                pomegranate 1kg                     3770.0           11.0
# 21               mamra badam 500g                     3560.0            2.0
# 5                    broccoli 1pc                     3300.0           11.0
# 7                    cashews 500g                     3280.0            4.0
# 32       premium jumbo dates 500g                     3260.0            4.0
# 10                desi papaya 1pc                     2100.0           21.0
# 29                      plum 500g                     2000.0            8.0
# 11         dried cranberries 500g                     1900.0            2.0
# 25                  naka pear 1kg                     1890.0            9.0
# 23              mosumbi local 1kg                     1815.0           11.0
# 3                 beauty pear 1kg                     1500.0            5.0
# 41                  s lettuce mix                     1430.0           13.0
# 17              imported kiwi box                     1385.0            7.0
# 46                    sitafal 1kg                     1300.0            5.0
# 50                     watermelon                     1240.0            8.0
# 24                  muskmelon 1pc                     1215.0            9.0
# 1                    baby spinach                     1210.0           11.0
# 16  imported blueberries 2punnets                     1200.0            2.0
# 15                honey awla 500g                     1080.0            3.0
# 35                red grapes 500g                     1050.0            3.0
# 13      gourmet black rasins 500g                     1000.0            2.0
# 27                      pineapple                      990.0            6.0
# 44                  s summercrisp                      990.0            9.0
# 39                   s butterhead                      990.0            9.0
# 20         japanese cucumber 500g                      900.0           10.0
# 19                  italian basil                      900.0           10.0
# 38                      s aragula                      880.0            8.0
# 9                        delivery                      870.0           58.0
# 12          elaichi banana 1dozen                      826.0            7.0
# 47                soft dates 500g                      800.0            2.0
# 18              indian apples 1kg                      695.0            3.0
# 14             green zucchini 1pc                      595.0            7.0
# 6    button white mushroom 2packs                      560.0            4.0
# 34               raipur guava 1kg                      555.0            3.0
# 42                      s romaine                      550.0            5.0
# 36        red yellow capsicum 1pc                      520.0            4.0
# 8            cherry tomatoes 250g                      510.0            6.0
# 51            yellow zucchini 1pc                      425.0            5.0
# 28            pink grapefruit 1kg                      380.0            1.0
# 43                    s spicy mix                      330.0            3.0
# 37           regular banana 1 doz                      300.0            3.0
# 48           turkish apricot 200g                      280.0            1.0
# 33            purple cabbage 1 pc                      255.0            3.0
# 40                    s curl kale                      220.0            2.0
# 2                  babycorn 1pack                      195.0            3.0

# %%
# Sort the DataFrame by date in descending order
df_sorted = combined_data_payment_completed.sort_values(by='date', ascending=False)

# Drop duplicates based on email column, keeping the first occurrence (most recent date)
df_unique = df_sorted.drop_duplicates(subset='name', keep='first')

# Create the DataFrame with 'name', 'email', and 'most_recent_date' columns
df_most_recent = df_unique[['name', 'email', 'date']].rename(columns={'date': 'Most_recent_Purchase_date'})
current_date=combined_data_payment_completed['date'].max()
# Print the resulting DataFrame
df_most_recent['Number of days after Purchase']=current_date-df_most_recent['Most_recent_Purchase_date']
df_most_recent=df_most_recent.reset_index()
df_most_recent.drop(columns='index')
# Out:
#                  name                      email Most_recent_Purchase_date  \
# 0       indrani jafar        ani.doley@gmail.com                2022-10-31
# 1     shwetha kallaje   shwethakallaje@gmail.com                2022-10-31
# 2         kerbi patel     kerbipatel66@gmail.com                2022-10-31
# 3   ashish billimoria    billimoriaash@gmail.com                2022-10-31
# 4            dinmeher          anish24@gmail.com                2022-10-31
# 5      mrs.ruchi wahi      wahiruchi80@gmail.com                2022-10-31
# 6               naina     naina.sharma@gmail.com                2022-10-31
# 7        nina dumasia   nina_dumasia@yahoo.co.in                2022-10-31
# 8              trupti         tmaskai5@gmail.com                2022-10-31
# 9        ritu kochhar        rchawla04@gmail.com                2022-10-30
# 10        parul kumar   2014parulkumar@gmail.com                2022-10-30
# 11         abha mehta      abhamehta26@gmail.com                2022-10-30
# 12            kanchan    samtani.kanchan@bcg.com                2022-10-30
# 13              neetu    neetu.vinayek@gmail.com                2022-10-28
# 14      jasma kapadia        jasmak999@yahoo.com                2022-10-28
# 15    priyanka taneja  4priyankataneja@gmail.com                2022-10-27
# 16        jaya prasad          anish24@gmail.com                2022-10-27
# 17    gitanjali anand          gma6567@gmail.com                2022-10-22
# 18    leena sivakumar  leena.sivakumar@gmail.com                2022-10-20
# 19       sonavi desai          sonavid@gmail.com                2022-10-18
# 20        toral patel      toral@accordindia.net                2022-10-17
# 21        meher mirza    mehermirza123@gmail.com                2022-10-17
# 22   michelle baptist      michbaptist@gmail.com                2022-10-16
# 23    dilnaaz zaiwala         zaiwalad@gmail.com                2022-10-16
# 24          padmasree      padmasree.r@gmail.com                2022-10-11
# 25      sanjay bandra          anish24@gmail.com                2022-10-05
# 26           preeti m          anish24@gmail.com                2022-10-05
# 27    sushama agarwal          anish24@gmail.com                2022-10-03
# 28        bharti shah          anish24@gmail.com                2022-10-03
#
#    Number of days after Purchase
# 0                         0 days
# 1                         0 days
# 2                         0 days
# 3                         0 days
# 4                         0 days
# 5                         0 days
# 6                         0 days
# 7                         0 days
# 8                         0 days
# 9                         1 days
# 10                        1 days
# 11                        1 days
# 12                        1 days
# 13                        3 days
# 14                        3 days
# 15                        4 days
# 16                        4 days
# 17                        9 days
# 18                       11 days
# 19                       13 days
# 20                       14 days
# 21                       14 days
# 22                       15 days
# 23                       15 days
# 24                       20 days
# 25                       26 days
# 26                       26 days
# 27                       28 days
# 28                       28 days

# %%
df_freq=df_most_recent.groupby('Most_recent_Purchase_date')['name'].size().reset_index()
# Create a scatter plot or line plot
plt.figure(figsize=(10, 6)) 

# Line plot
plt.plot(df_freq['Most_recent_Purchase_date'], df_freq['name'], marker='o')
plt.xlabel('Date')
plt.ylabel('Total Frequency')
plt.xticks(rotation=45)
plt.title('Customers most recent purchase by Date')
# Out:
# Text(0.5, 1.0, 'Customers most recent purchase by Date')

# %%
# Sort the DataFrame by date in descending order
df_sorted = combined_data_payment_completed.sort_values(by='date', ascending=True)

# Drop duplicates based on email column, keeping the first occurrence (most recent date)
df_unique = df_sorted.drop_duplicates(subset='name', keep='first')

# Create the DataFrame with 'name', 'email', and 'most_recent_date' columns
df_oldest_date = df_unique[['name', 'email', 'date']].rename(columns={'date': 'oldest_Purchase_date'})
# Print the resulting DataFrame

df_oldest_date=df_oldest_date.reset_index()
df_oldest_date.drop(columns='index')
# Out:
#                  name                      email oldest_Purchase_date
# 0           padmasree      padmasree.r@gmail.com           2022-10-02
# 1         parul kumar   2014parulkumar@gmail.com           2022-10-02
# 2          abha mehta      abhamehta26@gmail.com           2022-10-03
# 3         meher mirza    mehermirza123@gmail.com           2022-10-03
# 4     sushama agarwal          anish24@gmail.com           2022-10-03
# 5         bharti shah          anish24@gmail.com           2022-10-03
# 6             kanchan    samtani.kanchan@bcg.com           2022-10-03
# 7               naina     naina.sharma@gmail.com           2022-10-04
# 8    michelle baptist          anish24@gmail.com           2022-10-05
# 9            preeti m          anish24@gmail.com           2022-10-05
# 10      sanjay bandra          anish24@gmail.com           2022-10-05
# 11    shwetha kallaje   shwethakallaje@gmail.com           2022-10-06
# 12    dilnaaz zaiwala         zaiwalad@gmail.com           2022-10-06
# 13       sonavi desai          sonavid@gmail.com           2022-10-06
# 14      jasma kapadia        jasmak999@yahoo.com           2022-10-07
# 15    leena sivakumar  leena.sivakumar@gmail.com           2022-10-08
# 16  ashish billimoria    billimoriaash@gmail.com           2022-10-10
# 17    gitanjali anand          gma6567@gmail.com           2022-10-10
# 18        toral patel      toral@accordindia.net           2022-10-17
# 19              neetu    neetu.vinayek@gmail.com           2022-10-17
# 20     mrs.ruchi wahi      wahiruchi80@gmail.com           2022-10-17
# 21       ritu kochhar        rchawla04@gmail.com           2022-10-27
# 22    priyanka taneja   4priyankataneja@gmail.om           2022-10-27
# 23        jaya prasad          anish24@gmail.com           2022-10-27
# 24             trupti         tmaskai5@gmail.com           2022-10-31
# 25      indrani jafar        ani.doley@gmail.com           2022-10-31
# 26       nina dumasia   nina_dumasia@yahoo.co.in           2022-10-31
# 27           dinmeher          anish24@gmail.com           2022-10-31
# 28        kerbi patel     kerbipatel66@gmail.com           2022-10-31

# %%
name_amount=combined_data_payment_completed.groupby('name')['item payment amount(INR) '].sum().reset_index()
name_amount=name_amount.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
name_amount.drop(columns='index',inplace=True)
name_amount
# Out:
#                  name  item payment amount(INR)
# 0    michelle baptist                    18810.0
# 1     priyanka taneja                     8535.0
# 2       jasma kapadia                     7350.0
# 3           padmasree                     7335.0
# 4             kanchan                     5313.0
# 5     gitanjali anand                     4973.0
# 6        sonavi desai                     4875.0
# 7            preeti m                     4640.0
# 8               neetu                     4125.0
# 9               naina                     3828.0
# 10      sanjay bandra                     3800.0
# 11     mrs.ruchi wahi                     3670.0
# 12        parul kumar                     3464.0
# 13       ritu kochhar                     3345.0
# 14    shwetha kallaje                     1863.0
# 15      indrani jafar                     1840.0
# 16    leena sivakumar                     1630.0
# 17        jaya prasad                     1510.0
# 18        meher mirza                     1380.0
# 19    dilnaaz zaiwala                     1285.0
# 20        toral patel                      920.0
# 21  ashish billimoria                      890.0
# 22        kerbi patel                      535.0
# 23         abha mehta                      485.0
# 24           dinmeher                      410.0
# 25             trupti                      300.0
# 26       nina dumasia                      235.0
# 27    sushama agarwal                      235.0
# 28        bharti shah                      235.0

# %%
# Group data by 'name' and calculate the number of unique dates for each group
unique_days = combined_data_payment_completed.groupby('name')['date'].nunique().reset_index()

# Rename the column to 'unique_days'
unique_days=unique_days.sort_values(by='date',ascending=False)

unique_days = unique_days.rename(columns={'date': 'Number of times ordered this month','name':'Customer Name'})



unique_days
# Out:
#         Customer Name  Number of times ordered this month
# 19        parul kumar                                   4
# 7       jasma kapadia                                   4
# 0          abha mehta                                   3
# 13   michelle baptist                                   3
# 3     dilnaaz zaiwala                                   3
# 24    shwetha kallaje                                   3
# 9             kanchan                                   3
# 25       sonavi desai                                   2
# 22       ritu kochhar                                   2
# 18          padmasree                                   2
# 16              neetu                                   2
# 15              naina                                   2
# 1   ashish billimoria                                   2
# 14     mrs.ruchi wahi                                   2
# 12        meher mirza                                   2
# 11    leena sivakumar                                   2
# 5     gitanjali anand                                   2
# 10        kerbi patel                                   1
# 17       nina dumasia                                   1
# 8         jaya prasad                                   1
# 6       indrani jafar                                   1
# 20           preeti m                                   1
# 21    priyanka taneja                                   1
# 23      sanjay bandra                                   1
# 4            dinmeher                                   1
# 2         bharti shah                                   1
# 26    sushama agarwal                                   1
# 27        toral patel                                   1
# 28             trupti                                   1

# %%
df_sorted_amount=name_amount.sort_values(by='name')

df_sorted_amount = df_sorted_amount.rename(columns={'name':'Customer Name'})

unique_days=unique_days.sort_values(by='Customer Name')

merged_df = pd.merge(unique_days,df_sorted_amount, on='Customer Name', how='left')

merged_df['amount per order']=merged_df['item payment amount(INR) ']//merged_df['Number of times ordered this month']
df=merged_df.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
df.drop(columns='index',inplace=True)
df
# Out:
#         Customer Name  Number of times ordered this month  \
# 0    michelle baptist                                   3
# 1     priyanka taneja                                   1
# 2       jasma kapadia                                   4
# 3           padmasree                                   2
# 4             kanchan                                   3
# 5     gitanjali anand                                   2
# 6        sonavi desai                                   2
# 7            preeti m                                   1
# 8               neetu                                   2
# 9               naina                                   2
# 10      sanjay bandra                                   1
# 11     mrs.ruchi wahi                                   2
# 12        parul kumar                                   4
# 13       ritu kochhar                                   2
# 14    shwetha kallaje                                   3
# 15      indrani jafar                                   1
# 16    leena sivakumar                                   2
# 17        jaya prasad                                   1
# 18        meher mirza                                   2
# 19    dilnaaz zaiwala                                   3
# 20        toral patel                                   1
# 21  ashish billimoria                                   2
# 22        kerbi patel                                   1
# 23         abha mehta                                   3
# 24           dinmeher                                   1
# 25             trupti                                   1
# 26       nina dumasia                                   1
# 27    sushama agarwal                                   1
# 28        bharti shah                                   1
#
#     item payment amount(INR)   amount per order
# 0                     18810.0            6270.0
# 1                      8535.0            8535.0
# 2                      7350.0            1837.0
# 3                      7335.0            3667.0
# 4                      5313.0            1771.0
# 5                      4973.0            2486.0
# 6                      4875.0            2437.0
# 7                      4640.0            4640.0
# 8                      4125.0            2062.0
# 9                      3828.0            1914.0
# 10                     3800.0            3800.0
# 11                     3670.0            1835.0
# 12                     3464.0             866.0
# 13                     3345.0            1672.0
# 14                     1863.0             621.0
# 15                     1840.0            1840.0
# 16                     1630.0             815.0
# 17                     1510.0            1510.0
# 18                     1380.0             690.0
# 19                     1285.0             428.0
# 20                      920.0             920.0
# 21                      890.0             445.0
# 22                      535.0             535.0
# 23                      485.0             161.0
# 24                      410.0             410.0
# 25                      300.0             300.0
# 26                      235.0             235.0
# 27                      235.0             235.0
# 28                      235.0             235.0

# %%
top_customer=df.head(10)

top_customer_name=top_customer['Customer Name'].unique()

top_customer_detail=combined_data_payment_completed[combined_data_payment_completed['name'].isin(top_customer_name)]
top_customer_detail_grouped=top_customer_detail.groupby(['name','payment page title'])['item payment amount(INR) '].sum().reset_index()
top_customer_detail_grouped
# Out:
#                 name         payment page title  item payment amount(INR)
# 0    gitanjali anand               FRUIT BASKET                     4973.0
# 1      jasma kapadia     DRYFRUITS, SEEDS, NUTS                     2590.0
# 2      jasma kapadia               FRUIT BASKET                     2810.0
# 3      jasma kapadia  SALADS, EXOTIC VEGETABLES                     1950.0
# 4            kanchan               FRUIT BASKET                     2823.0
# 5            kanchan  SALADS, EXOTIC VEGETABLES                     2490.0
# 6   michelle baptist     DRYFRUITS, SEEDS, NUTS                    16200.0
# 7   michelle baptist               FRUIT BASKET                     2610.0
# 8              naina               FRUIT BASKET                     2798.0
# 9              naina  SALADS, EXOTIC VEGETABLES                     1030.0
# 10             neetu               FRUIT BASKET                     2140.0
# 11             neetu  SALADS, EXOTIC VEGETABLES                     1985.0
# 12         padmasree               FRUIT BASKET                     4990.0
# 13         padmasree  SALADS, EXOTIC VEGETABLES                     2345.0
# 14          preeti m     DRYFRUITS, SEEDS, NUTS                     4640.0
# 15   priyanka taneja     DRYFRUITS, SEEDS, NUTS                     7640.0
# 16   priyanka taneja               FRUIT BASKET                      895.0
# 17      sonavi desai               FRUIT BASKET                     4875.0

# %%
pivot_table = pd.pivot_table(top_customer_detail_grouped, values='item payment amount(INR) ', index='name', columns='payment page title', aggfunc='sum')

# Rename the columns
pivot_table.columns = ['DRYFRUITS, SEEDS, NUTS', 'FRUIT BASKET', 'SALADS, EXOTIC VEGETABLES']

# Reset the index
pivot_table.reset_index(inplace=True)
pivot_table.fillna(0,inplace=True)
pivot_table['Total Amount(INR) '] = pivot_table['DRYFRUITS, SEEDS, NUTS']+pivot_table['FRUIT BASKET']+pivot_table['SALADS, EXOTIC VEGETABLES']
pivot_table=pivot_table.sort_values(by='Total Amount(INR) ',ascending=False).reset_index()
pivot_table.drop(columns='index',inplace=True)
pivot_table
# Out:
#                name  DRYFRUITS, SEEDS, NUTS  FRUIT BASKET  \
# 0  michelle baptist                 16200.0        2610.0
# 1   priyanka taneja                  7640.0         895.0
# 2     jasma kapadia                  2590.0        2810.0
# 3         padmasree                     0.0        4990.0
# 4           kanchan                     0.0        2823.0
# 5   gitanjali anand                     0.0        4973.0
# 6      sonavi desai                     0.0        4875.0
# 7          preeti m                  4640.0           0.0
# 8             neetu                     0.0        2140.0
# 9             naina                     0.0        2798.0
#
#    SALADS, EXOTIC VEGETABLES  Total Amount(INR)
# 0                        0.0             18810.0
# 1                        0.0              8535.0
# 2                     1950.0              7350.0
# 3                     2345.0              7335.0
# 4                     2490.0              5313.0
# 5                        0.0              4973.0
# 6                        0.0              4875.0
# 7                        0.0              4640.0
# 8                     1985.0              4125.0
# 9                     1030.0              3828.0

# %%
pivot_table_p=pivot_table
pivot_table_p['FRUIT BASKET(percentage) ']=round(pivot_table_p['FRUIT BASKET']*100/pivot_table_p['Total Amount(INR) '],2)
pivot_table_p['DRYFRUITS, SEEDS, NUTS(percentage) ']=round(pivot_table_p['DRYFRUITS, SEEDS, NUTS']*100/pivot_table_p['Total Amount(INR) '],2)
pivot_table_p['SALADS, EXOTIC VEGETABLES(percentage) ']=round(pivot_table_p['SALADS, EXOTIC VEGETABLES']*100/pivot_table_p['Total Amount(INR) '],2)
#pivot_table_p['WEEKEND MIX FRUITS & EXOTICS(percentage) ']=round(pivot_table_p['WEEKEND MIX FRUITS & EXOTICS']*100/pivot_table_p['Total Amount(INR) '],2)

#pivot_table_p['HERBS & SALADS(percentage) ']=round(pivot_table_p['HERBS & SALADS']*100/pivot_table_p['Total Amount(INR) '],2)

pivot_table_p.drop(columns=['DRYFRUITS, SEEDS, NUTS','FRUIT BASKET','SALADS, EXOTIC VEGETABLES'],inplace=True)
pivot_table_p
# Out:
#                name  Total Amount(INR)   FRUIT BASKET(percentage)   \
# 0  michelle baptist             18810.0                      13.88
# 1   priyanka taneja              8535.0                      10.49
# 2     jasma kapadia              7350.0                      38.23
# 3         padmasree              7335.0                      68.03
# 4           kanchan              5313.0                      53.13
# 5   gitanjali anand              4973.0                     100.00
# 6      sonavi desai              4875.0                     100.00
# 7          preeti m              4640.0                       0.00
# 8             neetu              4125.0                      51.88
# 9             naina              3828.0                      73.09
#
#    DRYFRUITS, SEEDS, NUTS(percentage)   SALADS, EXOTIC VEGETABLES(percentage)
# 0                                86.12                                    0.00
# 1                                89.51                                    0.00
# 2                                35.24                                   26.53
# 3                                 0.00                                   31.97
# 4                                 0.00                                   46.87
# 5                                 0.00                                    0.00
# 6                                 0.00                                    0.00
# 7                               100.00                                    0.00
# 8                                 0.00                                   48.12
# 9                                 0.00                                   26.91

# %%
# bottom_customer=df.tail(10)

# bottom_customer_name=bottom_customer['Customer Name'].unique()

# bottom_customer_detail=combined_data_payment_completed[combined_data_payment_completed['name'].isin(bottom_customer_name)]
# bottom_customer_detail_grouped=bottom_customer_detail.groupby(['name','payment page title'])['item payment amount(INR) '].sum().reset_index()
# bottom_customer_detail_grouped
# pivot_table_bottom = pd.pivot_table(bottom_customer_detail_grouped, values='item payment amount(INR) ', index='name', columns='payment page title', aggfunc='sum')

# # # Rename the columns
# pivot_table_bottom.columns = ['FRUIT BASKET', 'SALADS, EXOTIC VEGETABLES','VEGETABLES','HERBS & SALADS']

# # Reset the index
# pivot_table_bottom.reset_index(inplace=True)
# pivot_table_bottom.fillna(0,inplace=True)
# pivot_table_bottom['Total Amount(INR) '] = pivot_table_bottom['FRUIT BASKET']+pivot_table_bottom['VEGETABLES']+pivot_table_bottom['SALADS, EXOTIC VEGETABLES']+pivot_table_bottom['HERBS & SALADS']
# pivot_table_bottom=pivot_table_bottom.sort_values(by='Total Amount(INR) ',ascending=False).reset_index()
# pivot_table_bottom.drop(columns='index',inplace=True)
# pivot_table_bottom

# %%
top_customer_detail.groupby('name')['item name'].unique().reset_index()
# Out:
#                name  \
# 0   gitanjali anand
# 1     jasma kapadia
# 2           kanchan
# 3  michelle baptist
# 4             naina
# 5             neetu
# 6         padmasree
# 7          preeti m
# 8   priyanka taneja
# 9      sonavi desai
#
#                                                                                                                                                                                                  item name
# 0  [sitafal 1kg, desi papaya 1pc, blueberries 2 box, watermelon, naka pear 1kg, elaichi banana 1dozen, pomegranate 1kg, pineapple, muskmelon 1pc, delivery, plum 500g, new zealand red apples 1kg, impo...
# 1  [beauty pear 1kg, imported kiwi box, pink grapefruit 1kg, new zealand red apples 1kg, delivery, avocados 2 pcs, red yellow capsicum 1pc, s curl kale, green zucchini 1pc, baby spinach, broccoli 1pc...
# 2  [sitafal 1kg, mandarin small oranges 1kg, plum 500g, avocados 2 pcs, delivery, elaichi banana 1dozen, naka pear 1kg, mosumbi local 1kg, muskmelon 1pc, italian basil, baby spinach, red yellow capsi...
# 3  [salted pista 500g, premium almonds 500g, gourmet black rasins 500g, cashews 500g, walnuts 500g, soft dates 500g, desi papaya 1pc, regular banana 1 doz, new zealand red apples 1kg, delivery, manda...
# 4  [desi papaya 1pc, watermelon, imported kiwi box, plum 500g, indian apples 1kg, naka pear 1kg, elaichi banana 1dozen, pomegranate 1kg, delivery, regular banana 1 doz, cherry tomatoes 250g, avocados...
# 5  [cherry tomatoes 250g, s lettuce mix, delivery, japanese cucumber 500g, s curl kale, s summercrisp, green zucchini 1pc, purple cabbage 1 pc, yellow zucchini 1pc, italian basil, avocados 2 pcs, s a...
# 6  [watermelon, blueberries 2 box, avocados 2 pcs, plum 500g, mandarin small oranges 1kg, naka pear 1kg, pomegranate 1kg, delivery, s summercrisp, cherry tomatoes 250g, japanese cucumber 500g, brocco...
# 7                                                                                                                                                                      [mamra badam 500g, honey awla 500g]
# 8                                          [watermelon, muskmelon 1pc, red grapes 500g, indian apples 1kg, delivery, walnuts 500g, premium almonds 500g, dried cranberries 500g, premium jumbo dates 500g]
# 9                                          [desi papaya 1pc, delivery, watermelon, mandarin small oranges 1kg, mosumbi local 1kg, new zealand red apples 1kg, plum 500g, pomegranate 1kg, red grapes 500g]

# %%
top1=top_customer_detail.groupby('name')['item name'].unique().reset_index()
top2=top_customer_detail.groupby('name')['item payment amount(INR) '].sum().reset_index()
merged=pd.merge(top1,top2,on='name',how='left')
merged=merged.sort_values(by="item payment amount(INR) ",ascending=False).reset_index()
merged.drop(columns='index')
# Out:
#                name  \
# 0  michelle baptist
# 1   priyanka taneja
# 2     jasma kapadia
# 3         padmasree
# 4           kanchan
# 5   gitanjali anand
# 6      sonavi desai
# 7          preeti m
# 8             neetu
# 9             naina
#
#                                                                                                                                                                                                  item name  \
# 0  [salted pista 500g, premium almonds 500g, gourmet black rasins 500g, cashews 500g, walnuts 500g, soft dates 500g, desi papaya 1pc, regular banana 1 doz, new zealand red apples 1kg, delivery, manda...
# 1                                          [watermelon, muskmelon 1pc, red grapes 500g, indian apples 1kg, delivery, walnuts 500g, premium almonds 500g, dried cranberries 500g, premium jumbo dates 500g]
# 2  [beauty pear 1kg, imported kiwi box, pink grapefruit 1kg, new zealand red apples 1kg, delivery, avocados 2 pcs, red yellow capsicum 1pc, s curl kale, green zucchini 1pc, baby spinach, broccoli 1pc...
# 3  [watermelon, blueberries 2 box, avocados 2 pcs, plum 500g, mandarin small oranges 1kg, naka pear 1kg, pomegranate 1kg, delivery, s summercrisp, cherry tomatoes 250g, japanese cucumber 500g, brocco...
# 4  [sitafal 1kg, mandarin small oranges 1kg, plum 500g, avocados 2 pcs, delivery, elaichi banana 1dozen, naka pear 1kg, mosumbi local 1kg, muskmelon 1pc, italian basil, baby spinach, red yellow capsi...
# 5  [sitafal 1kg, desi papaya 1pc, blueberries 2 box, watermelon, naka pear 1kg, elaichi banana 1dozen, pomegranate 1kg, pineapple, muskmelon 1pc, delivery, plum 500g, new zealand red apples 1kg, impo...
# 6                                          [desi papaya 1pc, delivery, watermelon, mandarin small oranges 1kg, mosumbi local 1kg, new zealand red apples 1kg, plum 500g, pomegranate 1kg, red grapes 500g]
# 7                                                                                                                                                                      [mamra badam 500g, honey awla 500g]
# 8  [cherry tomatoes 250g, s lettuce mix, delivery, japanese cucumber 500g, s curl kale, s summercrisp, green zucchini 1pc, purple cabbage 1 pc, yellow zucchini 1pc, italian basil, avocados 2 pcs, s a...
# 9  [desi papaya 1pc, watermelon, imported kiwi box, plum 500g, indian apples 1kg, naka pear 1kg, elaichi banana 1dozen, pomegranate 1kg, delivery, regular banana 1 doz, cherry tomatoes 250g, avocados...
#
#    item payment amount(INR)
# 0                    18810.0
# 1                     8535.0
# 2                     7350.0
# 3                     7335.0
# 4                     5313.0
# 5                     4973.0
# 6                     4875.0
# 7                     4640.0
# 8                     4125.0
# 9                     3828.0

# %%
detail_item=top_customer_detail[top_customer_detail['name']=='michelle baptist'].groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
detail_item_sort=detail_item.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
detail_item_sort.drop(columns='index')
# Out:
#                      item name  item payment amount(INR)   item quantity
# 0                 walnuts 500g                     4620.0            4.0
# 1         premium almonds 500g                     3600.0            4.0
# 2                 cashews 500g                     3280.0            4.0
# 3            salted pista 500g                     2900.0            2.0
# 4    gourmet black rasins 500g                     1000.0            2.0
# 5   new zealand red apples 1kg                      800.0            2.0
# 6              soft dates 500g                      800.0            2.0
# 7   mandarin small oranges 1kg                      680.0            2.0
# 8            blueberries 2 box                      615.0            1.0
# 9         regular banana 1 doz                      200.0            2.0
# 10            raipur guava 1kg                      185.0            1.0
# 11             desi papaya 1pc                      100.0            1.0
# 12                    delivery                       30.0            2.0

# %%
detail_item=top_customer_detail[top_customer_detail['name']=='priyanka taneja'].groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
detail_item_sort=detail_item.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
detail_item_sort.drop(columns='index')
# Out:
#                   item name  item payment amount(INR)   item quantity
# 0              walnuts 500g                     2310.0            2.0
# 1    dried cranberries 500g                     1900.0            2.0
# 2      premium almonds 500g                     1800.0            2.0
# 3  premium jumbo dates 500g                     1630.0            2.0
# 4           red grapes 500g                      350.0            1.0
# 5         indian apples 1kg                      240.0            1.0
# 6                watermelon                      155.0            1.0
# 7             muskmelon 1pc                      135.0            1.0
# 8                  delivery                       15.0            1.0

# %%
detail_item=top_customer_detail[top_customer_detail['name']=='jasma kapadia'].groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
detail_item_sort=detail_item.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
detail_item_sort.drop(columns='index')
# Out:
#                         item name  item payment amount(INR)   item quantity
# 0                    walnuts 500g                     2310.0            2.0
# 1                  avocados 2 pcs                     1200.0            2.0
# 2      new zealand red apples 1kg                      800.0            2.0
# 3                 beauty pear 1kg                      600.0            2.0
# 4   imported blueberries 2punnets                      600.0            1.0
# 5               imported kiwi box                      400.0            2.0
# 6             pink grapefruit 1kg                      380.0            1.0
# 7                    broccoli 1pc                      300.0            1.0
# 8            turkish apricot 200g                      280.0            1.0
# 9         red yellow capsicum 1pc                      130.0            1.0
# 10                   baby spinach                      110.0            1.0
# 11                    s curl kale                      110.0            1.0
# 12             green zucchini 1pc                       85.0            1.0
# 13                       delivery                       45.0            3.0

# %%
detail_item=top_customer_detail[top_customer_detail['name']=='kanchan'].groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()
detail_item_sort=detail_item.sort_values(by='item payment amount(INR) ',ascending=False).reset_index()
detail_item_sort.drop(columns='index').head(10)
# Out:
#                     item name  item payment amount(INR)   item quantity
# 0                broccoli 1pc                     1200.0            4.0
# 1  mandarin small oranges 1kg                      640.0            2.0
# 2              avocados 2 pcs                      600.0            1.0
# 3               italian basil                      540.0            6.0
# 4                   plum 500g                      500.0            2.0
# 5           mosumbi local 1kg                      330.0            2.0
# 6     red yellow capsicum 1pc                      260.0            2.0
# 7                 sitafal 1kg                      260.0            1.0
# 8                baby spinach                      220.0            2.0
# 9               naka pear 1kg                      210.0            1.0

# %% [markdown]
# ### visualization

# %%
date_amount=combined_data_payment_completed.groupby('date')['item payment amount(INR) '].sum().reset_index()
date_amount.sort_values(by='item payment amount(INR) ',ascending=False)

# %%
daily_sales = combined_data_payment_completed.groupby('date')['item payment amount(INR) '].sum().reset_index()


matplotlib.rcParams['figure.figsize']=(12,6)
plt.plot(daily_sales['date'], daily_sales['item payment amount(INR) '])
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Trends of Sales per Day')
plt.xticks(rotation=45)
plt.show()

# %%
combined_data_payment_completed['date']

# %%
daily_category_sales = combined_data_payment_completed.groupby(['date', 'payment page title'])['item payment amount(INR) '].sum().reset_index()

pivot_data =daily_category_sales.pivot(index='date', columns='payment page title', values='item payment amount(INR) ')

plt.figure(figsize=(20, 30))
pivot_data.plot(kind='bar', stacked=False)
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Sales per Day by Categories')
plt.legend()
plt.show()

# %% [markdown]
# this trend shows that on 21 june sales where heighest and fruit baskets where sold the most

# %%
daily_category_sales = combined_data_payment_completed.groupby(['date', 'payment page title'])['item quantity'].sum().reset_index()

pivot_data =daily_category_sales.pivot(index='date', columns='payment page title', values='item quantity')

plt.figure(figsize=(20, 30))
pivot_data.plot(kind='bar', stacked=False)
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.title('Sales per Day by Categories')
plt.legend()
plt.show()

# %% [markdown]
# This trend shows that on 15 june vegetables where sold in heighest quantity

# %% [markdown]
# ### Dryfruits

# %%
pd.set_option('display.max_colwidth', 200)

# %%
dryfruits=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='DRYFRUITS, SEEDS, NUTS']
dryfruits_grouped=dryfruits.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

# %%
dryfruits_unique_names=dryfruits.groupby('item name')['name'].unique().reset_index()

dryfruits_unique=dryfruits.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(dryfruits_unique,dryfruits_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,dryfruits_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount(INR) ','item quantity':'item sales quantity'})
merged_df

# %% [markdown]
# Table shows information regarding dry fruits categories item name,buyers count,sales amount,item sales quantity,buyers Name

# %%
dryfruit_date=dryfruits.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_dryfruits=dryfruits.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(dryfruit_date,unique_dryfruits, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)

# %% [markdown]
# Dryfruits sales this month

# %% [markdown]
# ### Fruits

# %%
fruits=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='FRUIT BASKET']
fruits_grouped=fruits.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

fruits_unique_names=fruits.groupby('item name')['name'].unique().reset_index()

fruits_unique=fruits.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(fruits_unique,fruits_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,fruits_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df

# %%
fruits_date=fruits.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_fruits=fruits.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(fruits_date,unique_fruits, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)

# %% [markdown]
# ### Vegetables

# %%
Vegetables=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='VEGETABLES']
Vegetables_grouped=Vegetables.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

Vegetables_unique_names=Vegetables.groupby('item name')['name'].unique().reset_index()

Vegetables_unique=Vegetables.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(Vegetables_unique,Vegetables_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,Vegetables_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df

# %%
Vegetables_date=Vegetables.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_Vegetables=Vegetables.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(Vegetables_date,unique_Vegetables, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)

# %% [markdown]
# ### Exotic vegetables

# %%
exotic_vegies=combined_data_payment_completed[combined_data_payment_completed['payment page title']=='SALADS, EXOTIC VEGETABLES']
exotic_vegies_grouped=exotic_vegies.groupby('item name')['item payment amount(INR) ','item quantity'].sum().reset_index()

exotic_vegies_unique_names=exotic_vegies.groupby('item name')['name'].unique().reset_index()

exotic_vegies_unique=exotic_vegies.groupby('item name')['name'].nunique().reset_index()

merged_df = pd.merge(exotic_vegies_unique,exotic_vegies_grouped, on='item name', how='left')

merged_df = pd.merge(merged_df,exotic_vegies_unique_names, on='item name', how='left')

merged_df = merged_df.rename(columns={'name_x': 'buyers count','name_y':'buyers Name','item payment amount(INR) ':'sales amount','item quantity':'item sales quantity'})
merged_df

# %%
exotic_vegies_date=exotic_vegies.groupby('date')['item payment amount(INR) '].sum().reset_index()
unique_exotic_vegies=exotic_vegies.groupby('date')['item name'].unique().reset_index()

merged_df = pd.merge(exotic_vegies_date,unique_exotic_vegies, on='date', how='left')
merged_df.sort_values(by='item payment amount(INR) ',ascending=False)

# %%
combined_data_payment_completed['name'].unique()

# %% [markdown]
# #### Indrani's data

# %%
indrani_data=combined_data_payment_completed[combined_data_payment_completed['name']=='indrani jafar']
indrani_data_grouped=indrani_data.groupby('item name')['item quantity','item payment amount(INR) '].sum().reset_index()
indrani_data_grouped.sort_values(by='item payment amount(INR) ',ascending=False)

# %%
indrani_orders = combined_data_payment_completed[(combined_data_payment_completed['name'] == 'indrani jafar')]



indrani_order_dates = indrani_orders.groupby('date')['item name'].unique().reset_index()
indrani_order_dates

# %%
combined_data_payment_completed[combined_data_payment_completed['name']=='yogesh thakkar']

# %% [markdown]
# # END
